# %%
import pandas as pd
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP
import hdbscan

# %%
df = pd.read_csv('ml_data/train.csv')
df.head(5)
# Out:
#                     URI                               Title  Year  \
# 0  https://boxd.it/3d1m     Transformers: Age of Extinction  2014
# 1  https://boxd.it/2NF6  Madagascar 3: Europe's Most Wanted  2012
# 2  https://boxd.it/fx08                      The First Omen  2024
# 3  https://boxd.it/2abQ                Terminator Salvation  2009
# 4  https://boxd.it/mpWM                       I Hate Summer  2020
#
#                                                 Plot           Director  \
# 0  As humanity picks up the pieces after the batt...        Michael Bay
# 1  Animal pals Alex, Marty, Melman, and Gloria ar...       Eric Darnell
# 2  When a young American woman is sent to Rome to...  Arkasha Stevenson
# 3  All grown up in post-apocalyptic 2018, John Co...                McG
# 4  Three families end up in the same rented house...     Massimo Venier
#
#             Genre1     Genre2           Genre3 Country  RatingAvg  \
# 0  Science Fiction  Adventure           Action     USA       2.12
# 1           Comedy     Family        Adventure     USA       3.03
# 2           Horror        NaN              NaN     USA       3.38
# 3         Thriller     Action  Science Fiction     USA       2.58
# 4           Comedy        NaN              NaN   Italy       3.25
#
#    RatingCount  MyRating
# 0     235666.0       1.0
# 1     296110.0       3.0
# 2     297652.0       3.5
# 3     146188.0       2.5
# 4       7717.0       3.0

# %%
# 1. Embedding model
sbert_model = SentenceTransformer("all-MiniLM-L6-v2")

# 2. CountVectorizer per il c-TF-IDF
vectorizer = CountVectorizer(
    stop_words="english",
    max_df=0.85,
    min_df=5
)

# 2. UMAP più globale e compatto
umap_model = UMAP(
    n_neighbors=75,     # scala globale→ outlier più vicini ai cluster
    n_components=20,     # dimensione ridotta “leggera”
    min_dist=0.0,       # punti molto compatti nel low-dim
    metric="cosine",
    random_state=42
)

# 3. HDBSCAN permissivo sui core points, “leaf” per meno outlier
hdbscan_model = hdbscan.HDBSCAN(
    min_cluster_size=20,       # cluster ≥ 20
    min_samples=1,             # densità minima più bassa possibile
    cluster_selection_method="leaf",
    prediction_data=True
)


# 4. Costruzione del topic model
topic_model = BERTopic(
    embedding_model=sbert_model,
    vectorizer_model=vectorizer,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    nr_topics="auto",
    calculate_probabilities=True,
    verbose=True
)

# %%
# 4. Fit + transform
docs = df["Plot"].tolist()
topics, probs = topic_model.fit_transform(docs)
# Out:
# 2025-05-25 20:04:18,007 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/44 [00:00<?, ?it/s]
# 2025-05-25 20:04:27,464 - BERTopic - Embedding - Completed ✓
# 2025-05-25 20:04:27,465 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-25 20:04:33,915 - BERTopic - Dimensionality - Completed ✓
# 2025-05-25 20:04:33,915 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-25 20:04:34,049 - BERTopic - Cluster - Completed ✓
# 2025-05-25 20:04:34,051 - BERTopic - Representation - Extracting topics using c-TF-IDF for topic reduction.
# 2025-05-25 20:04:34,110 - BERTopic - Representation - Completed ✓
# 2025-05-25 20:04:34,111 - BERTopic - Topic reduction - Reducing number of topics
# 2025-05-25 20:04:34,115 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-25 20:04:34,166 - BERTopic - Representation - Completed ✓
# 2025-05-25 20:04:34,166 - BERTopic - Topic reduction - Reduced number of topics from 17 to 13

# %%
topic_info = topic_model.get_topic_info()
print(topic_info[["Topic", "Count", "Name"]])
# Out:
#     Topic  Count                                Name
# 0      -1    764             -1_man_world_time_years
# 1       0    177              0_agent_man_world_case
# 2       1     99           1_woman_mother_home_house
# 3       2     64            2_planet_earth_crew_face
# 4       3     51            3_couple_york_road_night
# 5       4     47          4_quest_warrior_ring_power
# 6       5     45               5_story_film_rome_man
# 7       6     39               6_car_fight_drug_turn
# 8       7     31  7_relationship_school_decides_john
# 9       8     24       8_group_strangers_room_escape
# 10      9     22            9_princess_far_land_true
# 11     10     21     10_decision_begins_love_greater
# 12     11     20     11_attempts_success_years_night

# %%
df["Topic"] = topics
df["Topic_Prob"] = [p.max() if isinstance(p, (list, np.ndarray)) else None for p in probs]

for topic in sorted(df["Topic"].unique()):
    print(f"\nCluster {topic} — {len(df[df['Topic']==topic])} documenti")
    print(topic_model.get_topic_info()[topic_model.get_topic_info()["Topic"] == topic]['Name'].iloc[0])
    display(df[df["Topic"] == topic][["Title", "Plot", "Topic_Prob"]].sort_values(by="Topic_Prob", ascending=False).head(10))
# Out:
# Cluster -1 — 764 documenti
# -1_man_world_time_years
#                       Title  \
# 650       The Suicide Squad
# 1045  The Cat o' Nine Tails
# 976       Anatomy of a Fall
# 353         Licence to Kill
# 1051                   Hulk
# 141         Despicable Me 2
# 910            The Avengers
# 1112  A History of Violence
# 1183          Suicide Squad
# 663                       M
#
#                                                    Plot  Topic_Prob
# 650   Supervillains Harley Quinn, Bloodsport, Peacem...    0.352690
# 1045  A newsman works with a blind puzzle-solver to ...    0.345286
# 976   A woman is suspected of her husband's murder, ...    0.328354
# 353   After capturing the notorious drug lord Franz ...    0.326357
# 1051  Bruce Banner, a genetics researcher with a tra...    0.326112
# 141   Gru is recruited by the Anti-Villain League to...    0.325376
# 910   When an unexpected enemy emerges and threatens...    0.321899
# 1112  An average family is thrust into the spotlight...    0.309480
# 1183  From DC Comics comes the Suicide Squad, an ant...    0.307920
# 663   In this classic German thriller, Hans Beckert,...    0.300960
# Cluster 0 — 177 documenti
# 0_agent_man_world_case
#                     Title                                               Plot  \
# 40                Unknown  A man awakens from a coma, only to discover th...
# 122            Deadpool 2  Wisecracking mercenary Deadpool battles the ev...
# 64                     X2  Professor Charles Xavier and his team of genet...
# 70        Die Another Day  James Bond is sent to investigate the connecti...
# 113            Fight Club  A ticking-time-bomb insomniac and a slippery s...
# 102             Moonraker  After Drax Industries' Moonraker space shuttle...
# 106           Rear Window  A wheelchair-bound photographer spies on his n...
# 98   Strangers on a Train  Having met on a train, a smooth-talking psycho...
# 331             The Judge  A successful lawyer returns to his hometown fo...
# 219                  Rope  Two young men attempt to prove they committed ...
#
#      Topic_Prob
# 40          1.0
# 122         1.0
# 64          1.0
# 70          1.0
# 113         1.0
# 102         1.0
# 106         1.0
# 98          1.0
# 331         1.0
# 219         1.0
# Cluster 1 — 99 documenti
# 1_woman_mother_home_house
#                            Title  \
# 45                        Inside
# 84   Mamma Mia! Here We Go Again
# 90                     Incendies
# 433                Je Tu Il Elle
# 136                     Coraline
# 206                 The Grudge 2
# 165                     The Ward
# 263                        Smile
# 225              Pan's Labyrinth
# 356                   The Beyond
#
#                                                   Plot  Topic_Prob
# 45   Scarred for life after a harrowing near-death ...         1.0
# 84   Five years after meeting her three fathers, So...         1.0
# 90   A mother's last wishes send twins Jeanne and S...         1.0
# 433  A woman suffers a subdued psychological breakd...         1.0
# 136  Wandering her rambling old house in her boring...         1.0
# 206  A young woman encounters a malevolent supernat...         1.0
# 165  Kristen, a troubled young woman, is captured b...         1.0
# 263  After witnessing a bizarre, traumatic incident...         1.0
# 225  Living with her tyrannical stepfather in a new...         1.0
# 356  A young woman inherits an old hotel in Louisia...         1.0
# Cluster 2 — 64 documenti
# 2_planet_earth_crew_face
#                               Title  \
# 62                       Prometheus
# 52                           Alien³
# 97          Star Trek Into Darkness
# 66   Dawn of the Planet of the Apes
# 646                       The Thing
# 455              Alien Resurrection
# 395                       Star Trek
# 670                    Annihilation
# 478         The Cloverfield Paradox
# 493                          WALL·E
#
#                                                   Plot  Topic_Prob
# 62   A team of explorers discover a clue to the ori...         1.0
# 52   After escaping with Newt and Hicks from the al...         1.0
# 97   When the crew of the Enterprise is called back...         1.0
# 66   A group of scientists in San Francisco struggl...         1.0
# 646  In the winter of 1982, a twelve-man research t...         1.0
# 455  Two hundred years after Lt. Ripley died, a gro...         1.0
# 395  The fate of the galaxy rests in the hands of b...         1.0
# 670  A biologist signs up for a dangerous, secret e...         1.0
# 478  Orbiting above a planet on the brink of war, s...         1.0
# 493  What if mankind had to leave Earth and somebod...         1.0
# Cluster 3 — 51 documenti
# 3_couple_york_road_night
#                                                  Title  \
# 4                                        I Hate Summer
# 15                                            La Haine
# 60                          Nothing Left to Do But Cry
# 434                                         Last Vegas
# 142                                         Past Lives
# 209                                      The Big Chill
# 414                               Friends: The Reunion
# 389                          Three Identical Strangers
# 1317  The Adventures of Priscilla, Queen of the Desert
# 1382                        There's No Place Like Home
#
#                                                    Plot  Topic_Prob
# 4     Three families end up in the same rented house...         1.0
# 15    After a chaotic night of rioting in a marginal...         1.0
# 60    Two 20th-century friends accidentally stumble ...         1.0
# 434   Aging pals Billy, Paddy, Archie, and Sam have ...         1.0
# 142   After decades apart, childhood friends Nora an...         1.0
# 209   Seven old college friends gather for a weekend...         1.0
# 414   The cast of Friends reunites for a once-in-a-l...         1.0
# 389   New York, 1980. Three complete strangers accid...         1.0
# 1317  Two drag queens and a transgender woman contra...         1.0
# 1382  An extended family reunites after a long time ...         1.0
# Cluster 4 — 47 documenti
# 4_quest_warrior_ring_power
#                                                   Title  \
# 151                                              Eragon
# 114                                       Kung Fu Panda
# 109                                             Aquaman
# 198                            Dragon Ball Super: Broly
# 164                         Kingsman: The Golden Circle
# 1236                    Dragon Ball Z: Resurrection 'F'
# 1140              The Lord of the Rings: The Two Towers
# 491          How to Train Your Dragon: The Hidden World
# 549   The Lord of the Rings: The Fellowship of the Ring
# 788                                   Dragon Ball DAIMA
#
#                                                    Plot  Topic_Prob
# 151   In his homeland of Alagaesia, a farm boy happe...         1.0
# 114   When the Valley of Peace is threatened, lazy P...         1.0
# 109   Half-human, half-Atlantean Arthur Curry is tak...         1.0
# 198   Earth is peaceful following the Tournament of ...         1.0
# 164   When an attack on the Kingsman headquarters ta...         1.0
# 1236  One peaceful day on Earth, two remnants of Fri...         1.0
# 1140  Frodo Baggins and the other members of the Fel...         1.0
# 491   As Hiccup fulfills his dream of creating a pea...         1.0
# 549   Young hobbit Frodo Baggins, after inheriting a...         1.0
# 788   Mysteriously transformed into mini versions of...         1.0
# Cluster 5 — 45 documenti
# 5_story_film_rome_man
#                                  Title  \
# 153       Fantozzi: White Collar Blues
# 221                             Loro 2
# 306                        Rose Island
# 181             Welcome Mr. President!
# 178                        The Traitor
# 406                                 8½
# 868                   The Great Beauty
# 1098        Tear Along the Dotted Line
# 590                             Loro 1
# 558   The Night Before the Exams Today
#
#                                                    Plot  Topic_Prob
# 153   A good-natured but unlucky Italian is constant...         1.0
# 221   "Loro", in two parts, is a period movie that c...         1.0
# 306   In 1968, engineer Giorgio Rosa established the...         1.0
# 181   In a small mountain village lives a man with a...         1.0
# 178   Palermo, Sicily, 1980. Mafia member Tommaso Bu...         1.0
# 406   Guido Anselmi, a film director, finds himself ...         1.0
# 868   Jep Gambardella has seduced his way through th...         1.0
# 1098  A cartoonist in Rome with his armadillo-for-a-...         1.0
# 590   "Loro", in two parts, is a period movie that c...         1.0
# 558   In 2006, as World Cup fever sweeps Italy, high...         1.0
# Cluster 6 — 39 documenti
# 6_car_fight_drug_turn
#                        Title  \
# 170                  Rocky V
# 269      A Fish Called Wanda
# 546        Pineapple Express
# 519                Rocky III
# 486   Brawl in Cell Block 99
# 391                    Rocky
# 369            The Gentlemen
# 1402                 Savages
# 1099            Rocky Balboa
# 1056              Snake Eyes
#
#                                                    Plot  Topic_Prob
# 170   A lifetime of taking shots has ended Rocky’s c...         1.0
# 269   While a diamond advocate attempts to steal a c...         1.0
# 546   A stoner and his dealer are forced to go on th...         1.0
# 519   After an intense fight with Clubber Lang and t...         1.0
# 486   After working as a drug courier and getting in...         1.0
# 391   An uneducated collector for a Philadelphia loa...         1.0
# 369   American expat Mickey Pearson has built a high...         1.0
# 1402  Pot growers Ben and Chon face off against the ...         1.0
# 1099  His wife is dead and his son hates him, but th...         1.0
# 1056  All bets are off when shady homicide cop Rick ...         1.0
# Cluster 7 — 31 documenti
# 7_relationship_school_decides_john
#                          Title  \
# 33     Scott Pilgrim Takes Off
# 53                  Unfaithful
# 140  Hannah Montana: The Movie
# 186                    Sweetie
# 162               Dead Ringers
# 234      High School Musical 2
# 236             A Star Is Born
# 417                   Big Eyes
# 267         A Walk to Remember
# 271            The Idea of You
#
#                                                   Plot  Topic_Prob
# 33   Scott Pilgrim meets the girl of his dreams, Ra...         1.0
# 53   Connie is a wife and mother whose 11-year marr...         1.0
# 140  When Miley Stewart (aka pop-star Hannah Montan...         1.0
# 186  The buttoned-down, superstitious Kay is attemp...         1.0
# 162  Elliot, a successful gynecologist, works at th...         1.0
# 234  The East High Wildcats are gearing up for big ...         1.0
# 236  Seasoned musician Jackson Maine discovers — an...         1.0
# 417  In the late 1950s and early '60s, artist Walte...         1.0
# 267  When the popular, restless Landon Carter is fo...         1.0
# 271  40-year-old single mom Solène begins an unexpe...         1.0
# Cluster 8 — 24 documenti
# 8_group_strangers_room_escape
#                          Title  \
# 68           Fear Street: 1978
# 217                     Circle
# 261                  Contagion
# 343           Dawn of the Dead
# 368                      [REC]
# 376                Cabin Fever
# 397  Resident Evil: Apocalypse
# 400   Night of the Living Dead
# 428        One Cut of the Dead
# 457                     Demons
#
#                                                   Plot  Topic_Prob
# 68   In 1978, two rival groups at Camp Nightwing mu...         1.0
# 217  In a massive, mysterious chamber, fifty strang...         1.0
# 261  As an epidemic of a lethal airborne virus - th...         1.0
# 343  During an ever-growing epidemic of zombies tha...         1.0
# 368  A television reporter and cameraman follow eme...         1.0
# 376  A group of five college graduates rent a cabin...         1.0
# 397  As the city is locked down under quarantine, A...         1.0
# 400  A group of strangers trapped in a farmhouse fi...         1.0
# 428  Real zombies arrive and terrorize the crew of ...         1.0
# 457  A group of people are trapped in a West Berlin...         1.0
# Cluster 9 — 22 documenti
# 9_princess_far_land_true
#                                Title  \
# 175                           Barbie
# 201                  The Magic Flute
# 235                           Frozen
# 238                  Sleeping Beauty
# 379  Snow White and the Seven Dwarfs
# 390             Beauty and the Beast
# 394                            Bambi
# 430                            Shrek
# 481              Shrek Forever After
# 484                          Aladdin
#
#                                                   Plot  Topic_Prob
# 175  Barbie and Ken are having the time of their li...         1.0
# 201  The Queen of the Night enlists a handsome prin...         1.0
# 235  Young princess Anna of Arendelle dreams about ...         1.0
# 238  Cursed to die by the evil fairy Maleficent whe...         1.0
# 379  A beautiful girl, Snow White, takes refuge in ...         1.0
# 390  Follow the adventures of Belle, a bright young...         1.0
# 394  Bambi's tale unfolds from season to season as ...         1.0
# 430  It ain't easy bein' green -- especially if you...         1.0
# 481  A bored and domesticated Shrek pacts with deal...         1.0
# 484  In the boorish city of Agrabah, kind-hearted s...         1.0
# Cluster 10 — 21 documenti
# 10_decision_begins_love_greater
#                                                  Title  \
# 46   Humanist Vampire Seeking Consenting Suicidal P...
# 65                                       After We Fell
# 341                                  After We Collided
# 351          The Twilight Saga: Breaking Dawn – Part 2
# 354                                         Black Swan
# 442                                   After Ever Happy
# 475                                   After Everything
# 498                                      Roman Holiday
# 536                                        The Outside
# 543                                          Repulsion
#
#                                                   Plot  Topic_Prob
# 46   Sasha is a young vampire with a serious proble...         1.0
# 65   Just as Tessa's life begins to become unglued,...         1.0
# 341  Tessa finds herself struggling with her compli...         1.0
# 351  After the birth of Renesmee, the Cullens gathe...         1.0
# 354  The story of Nina, a ballerina in a New York C...         1.0
# 442  As a shocking truth about a couple's families ...         1.0
# 475  Besieged by writer’s block and the crushing br...         1.0
# 498  Overwhelmed by her suffocating schedule, touri...         1.0
# 536  Longing to fit in at work, awkward Stacey begi...         1.0
# 543  Beautiful young manicurist Carole suffers from...         1.0
# Cluster 11 — 20 documenti
# 11_attempts_success_years_night
#                      Title                                               Plot  \
# 57          Death Sentence  Nick Hume is a mild-mannered executive with a ...
# 108                   Soul  Joe Gardner is a middle school teacher with a ...
# 250     The King of Comedy  Aspiring comic Rupert Pupkin attempts to achie...
# 319                Network  When veteran anchorman Howard Beale is forced ...
# 374     The Social Network  In 2003, Harvard undergrad and computer progra...
# 388             The Intern  70-year-old widower Ben Whittaker has discover...
# 439             Green Book  Tony Lip, a bouncer in 1962, is hired to drive...
# 482      Shaun of the Dead  Shaun lives a supremely uneventful life, which...
# 492  The Devil Wears Prada  Andy moves to New York to work in the fashion ...
# 615               17 Again  On the brink of a midlife crisis, 30-something...
#
#      Topic_Prob
# 57          1.0
# 108         1.0
# 250         1.0
# 319         1.0
# 374         1.0
# 388         1.0
# 439         1.0
# 482         1.0
# 492         1.0
# 615         1.0
