# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import names
from sklearn.cluster import MiniBatchKMeans
import joblib

# %%
sbert = SentenceTransformer("all-MiniLM-L6-v2")

# %%
df = pd.read_csv('ml_data/all_movies.csv')
df.rename(columns={'name': 'Title'}, inplace=True)
df.dropna(subset=['description'], inplace=True)
df = df.head(n=50000)
df['Plot'] = df['tagline'].fillna('') + "\n" + df['description']
docs = df["Plot"].tolist()

# embeddings = sbert.encode(docs, show_progress_bar=True)
embeddings = joblib.load("ml_data/all_movies_emb.pkl")

# %%
df = pd.read_csv('ml_data/train.csv')
docs = df['Plot'].tolist()

# embeddings = sbert.encode(docs, show_progress_bar=True)
embeddings = joblib.load("ml_data/train_emb.pkl")

# %% [markdown]
# ## BERTopic

# %%
from bertopic import BERTopic
from umap import UMAP
import hdbscan

# %%
# 1) Embedding e vectorizer
sbert = SentenceTransformer("all-MiniLM-L6-v2")
vect  = CountVectorizer(stop_words="english", min_df=10, max_df=0.8)

# 2) UMAP: scala più locale (n_neighbors↓) e min_dist leggermente >0
umap = UMAP(
    n_neighbors=25,
    n_components=15,     # preserva più info semantica
    min_dist=0.1,
    metric="cosine",
    random_state=42
)

# 3) HDBSCAN super‐permissivo
hdb = hdbscan.HDBSCAN(
    min_cluster_size=20,
    min_samples=1,
    cluster_selection_method="leaf",
    cluster_selection_epsilon=0.15,  # **chiave**: rilassa i confini
    prediction_data=True
)

topic_model = BERTopic(
    embedding_model=sbert,
    vectorizer_model=vect,
    umap_model=umap,
    hdbscan_model=hdb,
    nr_topics="auto",
    calculate_probabilities=True,
    verbose=True
)

# %%
topics, probs = topic_model.fit_transform(docs)
# Out:
# 2025-05-26 09:51:12,699 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/1563 [00:00<?, ?it/s]
# 2025-05-26 09:51:52,370 - BERTopic - Embedding - Completed ✓
# 2025-05-26 09:51:52,371 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-26 09:53:30,620 - BERTopic - Dimensionality - Completed ✓
# 2025-05-26 09:53:30,625 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-26 09:57:25,650 - BERTopic - Cluster - Completed ✓
# 2025-05-26 09:57:25,652 - BERTopic - Representation - Extracting topics using c-TF-IDF for topic reduction.
# 2025-05-26 09:57:27,687 - BERTopic - Representation - Completed ✓
# 2025-05-26 09:57:27,688 - BERTopic - Topic reduction - Reducing number of topics
# 2025-05-26 09:57:27,795 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-26 09:57:29,594 - BERTopic - Representation - Completed ✓
# 2025-05-26 09:57:29,601 - BERTopic - Topic reduction - Reduced number of topics from 237 to 36

# %%
topic_info = topic_model.get_topic_info()
print(topic_info[["Topic", "Count", "Name"]])
# Out:
#     Topic  Count                                     Name
# 0      -1  29986                -1_love_family_woman_film
# 1       0  18105                   0_film_love_school_war
# 2       1    599                 1_team_game_fight_career
# 3       2    101              2_food_france_business_deal
# 4       3    100           3_dance_competition_york_stage
# 5       4     93                4_future_human_earth_like
# 6       5     90                      5_race_car_road_win
# 7       6     72                 6_dance_fun_friends_gets
# 8       7     63            7_star_documentary_far_making
# 9       8     52             8_dr_investigate_john_series
# 10      9     52               9_queen_magic_king_village
# 11     10     51           10_modern_film_passion_leading
# 12     11     47            11_gang_mystery_adventure_fun
# 13     12     37  12_game_relationship_especially_brother
# 14     13     36            13_magic_assistant_act_powers
# 15     14     32            14_dream_american_fight_group
# 16     15     30                  15_gang_team_learns_red
# 17     16     29          16_explores_real_dark_political
# 18     17     28         17_released_finding_good_believe
# 19     18     27          18_ancient_high_legend_discover
# 20     19     27                19_king_rise_trouble_rock
# 21     20     26        20_school_children_family_parents
# 22     21     26       21_president_political_richard_run
# 23     22     25              22_classic_boy_tale_magical
# 24     23     25         23_mountain_limits_reach_attempt
# 25     24     25             24_shop_london_business_town
# 26     25     24         25_adaptation_father_uncle_queen
# 27     26     24         26_season_woman_run_consequences
# 28     27     23        27_legendary_power_friends_battle
# 29     28     22                 28_team_school_high_camp
# 30     29     22       29_murder_clear_assistant_develops
# 31     30     21         30_california_led_killer_perfect
# 32     31     20          31_fate_ordinary_tells_decision
# 33     32     20            32_earth_forces_century_space
# 34     33     20      33_war_military_documentary_feature
# 35     34     20       34_captain_travel_friends_involved

# %% [markdown]
# ## K-Means

# %%
K = 100
kmeans = MiniBatchKMeans(
    n_clusters=K,
    batch_size=2048,
    random_state=99
)
labels = kmeans.fit_predict(embeddings)

# %%
# 1. Associa i label al DataFrame
df["Topic"] = labels

# 2. Estrai la matrice conteggi per tutto il corpus
vectorizer = CountVectorizer(stop_words="english", min_df=20, max_df=0.8)
X_counts = vectorizer.fit_transform(docs)  # docs = lista di tutte le trame

# 3. Somma i counts per cluster
K = kmeans.n_clusters
term_counts_per_cluster = np.zeros((K, X_counts.shape[1]))
for i, lab in enumerate(labels):
    term_counts_per_cluster[lab] += X_counts[i].toarray().ravel()

# 4. Calcola TF di classe e IDF di classe
tf_c = term_counts_per_cluster / term_counts_per_cluster.sum(axis=1, keepdims=True)
clusters_with_term = np.count_nonzero(term_counts_per_cluster > 0, axis=0)
idf_c = np.log(K / clusters_with_term)

# 5. Costruisci la matrice c-TF-IDF
c_tf_idf = tf_c * idf_c

# 6. Estrai le top-10 keywords per cluster
terms = np.array(vectorizer.get_feature_names_out())
cluster_keywords = {
    c: terms[np.argsort(-c_tf_idf[c])[:25]].tolist()
    for c in range(K)
}

# 7. Rimuovi nomi propri con NLTK
nltk.download("names", quiet=True)
all_names = set(n.lower() for n in names.words())

filtered_cluster_keywords = {}
for c, kws in cluster_keywords.items():
    nonames = [w for w in kws if w.lower() not in all_names]
    # prendi le prime 4 parole non-nome
    filtered_cluster_keywords[c] = nonames[:5]

# 8. Ricostruisci topic_info (senza colonna Keywords)
counts = df["Topic"].value_counts().sort_index()
topic_info = pd.DataFrame({
    "Topic": counts.index,
    "Count": counts.values,
    "Name":  [", ".join(filtered_cluster_keywords[t]) for t in counts.index]
})

# %%
for topic in sorted(df["Topic"].unique()):
    print(f"\n=== Topic {topic}: {', '.join(filtered_cluster_keywords[topic])} ===")
    print(df[df["Topic"] == topic]['Title'].to_list()[:20])
# Out:
# === Topic 0: adventure, crew, heart, woman, forces ===
# ["Pirates of the Caribbean: At World's End", 'Pirates of the Caribbean: On Stranger Tides', "Pirates of the Caribbean: Dead Man's Chest", 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Pirates of the Caribbean: Dead Men Tell No Tales']
#
# === Topic 1: war, story, lives, world, future ===
# ['The Shape of Water', 'Shadow of Fire', 'Cloud Atlas', 'The Brutalist', '300', "Don't Be Bad", 'Napoleon', 'Life Is Beautiful', "Schindler's List", 'The Lost City of Z', 'The Legend of 1900', "Guillermo del Toro's Pinocchio", 'Babylon', 'The Zone of Interest', 'Tear Along the Dotted Line', 'The American Backyard', 'Green Border', 'Jojo Rabbit']
#
# === Topic 2: bond, car, left, drug, inside ===
# ['Blade Runner 2049', 'Blade Runner', 'Licence to Kill', 'Good Bye, Lenin!', 'Becoming Bond', "That's Life"]
#
# === Topic 3: forces, evil, family, agent, child ===
# ['The Devil All the Time', 'Fantastic Beasts and Where to Find Them', 'CODA', 'Hellboy']
#
# === Topic 4: killer, murder, woman, girl, car ===
# ['The Nice Guys', 'Sister Act', 'Rear Window', "The Girl Who Kicked the Hornet's Nest", 'Chloe', 'The Ward', 'Kill Bill: Vol. 1', 'Knife+Heart', 'Thesis', 'Final Destination 2', 'Crash', 'Gone Girl', 'Friday the 13th', 'The Quick and the Dead', 'Dressed to Kill', 'The Fate of the Furious', 'Perfect Blue', 'Anatomy of a Murder', 'True Grit', 'Creep 2']
#
# === Topic 5: save, house, forced, personal, student ===
# ['Deadpool 2', 'Kingsman: The Golden Circle', 'Vice', 'Election', 'Deadpool', 'Saw IV', 'Deadpool & Wolverine', 'Videodrome']
#
# === Topic 6: alien, great, island, father, ancient ===
# ['Jaws', 'The Wild Robot', 'Godzilla', 'Prey', 'The Birds', 'The Host', 'Finding Nemo', 'Predators', 'Lucky and Zorba']
#
# === Topic 7: house, forced, unexpected, couple, sinister ===
# ['Carnage', 'Perfect Strangers', 'Superbad', 'Trap', 'Black Christmas', 'Neighbors', 'Human Capital']
#
# === Topic 8: war, doctor, army, american, attempt ===
# ['Frantic', 'The Men Who Stare at Goats', 'The French Dispatch', 'Shutter Island', 'A Million Ways to Die in the West', 'The Wicker Man', 'Mine', 'The Beguiled', 'You Were Never Really Here', 'Civil War', 'Haywire', 'ACAB : All Cops Are Bastards', 'Da 5 Bloods']
#
# === Topic 9: human, taken, come, journey, ex ===
# ['Aquaman', 'Rocky V', 'Rocky Balboa']
#
# === Topic 10: relationship, end, woman, father, following ===
# ['Vicky Cristina Barcelona', 'The Holiday', 'Portrait of a Lady on Fire', 'Three Men and a Leg']
#
# === Topic 11: drug, police, government, crime, gang ===
# ['Killers of the Flower Moon', 'Reservoir Dogs', 'Sleepers', 'The Legend of Al, John and Jack', 'The Departed', 'The Big Short', 'Jackie', 'The Trial of the Chicago 7', 'Queer', 'The Good, the Bad and the Ugly', 'Money Shot: The Pornhub Story', 'Judas and the Black Messiah', 'The Purge: Election Year', "All the President's Men", 'Bubba Ho-tep', 'The Ballad of Buster Scruggs', 'Point Break', 'Scarface', 'Angel Heart', 'National Treasure: Book of Secrets']
#
# === Topic 12: doctor, children, american, mother, house ===
# ['The Help', 'Roman Holiday', 'Forever-Forever', 'Lady Bird', 'The Water', 'The Others', 'Fifty Shades of Grey', 'Valerie and Her Week of Wonders', 'The Marvels', 'Wild Strawberries', 'Black Widow']
#
# === Topic 13: tries, man, begins, drug, lives ===
# ['Strangers on a Train', 'Fight Club', "One Flew Over the Cuckoo's Nest", 'Baby Reindeer', 'Italiano medio', 'Falling Down', 'Limitless', 'American Fiction', 'The Father', 'Nightmare Alley', 'A Clockwork Orange', 'Forrest Gump', 'A Dangerous Method']
#
# === Topic 14: mother, alien, killed, little, wants ===
# ['Psycho', 'Scary Movie 4', 'Turning Red', 'Scary Movie 3', 'Mama', "Mr. Magorium's Wonder Emporium", 'Days of Being Wild', 'Missing', 'Tangled']
#
# === Topic 15: drug, crime, fight, turn, police ===
# ['Airplane!', 'Ali G Indahouse', 'Pulp Fiction', 'Tetsuo II: Body Hammer', 'A Fish Called Wanda', 'Dogman', '21', 'A Fistful of Dollars', 'Rocky', 'First Blood', 'Brawl in Cell Block 99', 'Pineapple Express', 'Baby Driver', 'Snatch', 'Edge of Tomorrow', 'Escape from New York', 'The Equalizer', 'V for Vendetta', 'Killing Them Softly', 'DodgeBall: A True Underdog Story']
#
# === Topic 16: alien, space, earth, little, planet ===
# ['Alien³', 'District 9', 'Alien Resurrection', 'The Fly', 'The Thing', 'Annihilation', 'AVP: Alien vs. Predator', 'Paul', 'E.T. the Extra-Terrestrial', 'Aliens', 'Journey to the Center of the Earth', 'Gravity']
#
# === Topic 17: remote, journey, family, american, strange ===
# ['I Hate Summer', 'Midsommar', 'Captain Fantastic', 'The Boy', 'The Lighthouse', 'The Murmuring', 'Here', 'Nomadland', 'Minari', 'Koyaanisqatsi', 'The Sacrament', 'The Witch', 'Speak No Evil']
#
# === Topic 18: killer, murder, seemingly, dead, attempt ===
# ['QT8: The First Eight', 'Enter the Void', 'The House That Jack Built', 'Rope', 'Gosford Park', 'Blow Out', 'Seven Psychopaths', 'M', 'Taste of Cherry', 'Deathtrap', "Omicidio all'italiana", 'No Country for Old Men', 'Cure', 'Deep Red', 'Jack Reacher', 'Saw X', 'Memories of Murder', 'The Last Prosecco', 'Se7en']
#
# === Topic 19: detective, dead, killer, wife, agent ===
# ['Last Night of Amore', 'The Trouble with Harry', 'Naked Lunch', 'Network', 'Saw', 'Decision to Leave', 'Saw II', 'Saw III', 'Twilight', 'Knives Out', 'Saw VI', 'Saw V', 'Glass Onion']
#
# === Topic 20: couple, woman, york, night, young ===
# ['Before Sunrise', 'Hostel', 'Nothing Left to Do But Cry', 'Barbarian', 'House of 1000 Corpses', 'The Menu', "Rosemary's Baby", 'Y Tu Mamá También', 'A Rainy Day in New York', 'Wild at Heart', 'Io Capitano']
#
# === Topic 21: story, boy, film, journey, brother ===
# ['The Northman', 'Boyhood', 'Evil Dead Rise', 'Eragon', 'The First King', 'Bāhubali 2: The Conclusion', 'Robin Hood', 'Faust', 'Avatar: The Way of Water', 'Encanto', 'Dogman', 'Metropolis', 'Mad Max Beyond Thunderdome', 'Mr. Nobody', 'Son of the White Mare', 'Harry Potter 20th Anniversary: Return to Hogwarts', 'They Call Me Trinity', 'Labyrinth']
#
# === Topic 22: woman, revenge, young, car, seeks ===
# ['The First Omen', 'Bird Box', 'Inside', '10 Cloverfield Lane', 'Woman in the Dunes', 'Amores Perros', 'The Grudge 2', 'Smile', 'Klute', 'Okja', 'Final Destination 3', 'The Beyond', 'Irreversible', 'Je Tu Il Elle', 'Colossal', 'Lucy', 'Poor Things', 'Cam', 'Rabid', 'Ju-on: The Grudge']
#
# === Topic 23: gang, future, strange, small, day ===
# ['The Nightmare Before Christmas', 'Black Mirror: White Christmas', 'A Christmas Carol', 'Winnie the Pooh: A Very Merry Pooh Year', 'Red One', 'Gremlins', 'The Muppet Christmas Carol', 'Groundhog Day', 'The Santa Claus Gang', "FX's A Christmas Carol"]
#
# === Topic 24: men, powerful, force, led, band ===
# ['X2', 'X-Men: First Class', 'X-Men', 'X-Men: Days of Future Past', 'X-Men: Apocalypse', 'Logan', 'Dark Phoenix', 'X-Men Origins: Wolverine', 'X-Men: The Last Stand']
#
# === Topic 25: crime, high, city, protect, powers ===
# ['Spider-Man', 'Bruce Almighty', 'Spider-Man 2', 'Spider-Man: Across the Spider-Verse', 'The Dark Knight Rises', 'Joker', 'The Amazing Spider-Man', 'Batman', 'The Batman', 'Batman Begins', 'The Dark Knight', 'The Amazing Spider-Man 2', 'Justice League', 'Spider-Man: No Way Home']
#
# === Topic 26: quest, little, forever, existence, leads ===
# ['Yes Man', 'The Cosmos on the Commode', 'Night at the Museum: Secret of the Tomb', 'Sausage Party', 'Night at the Museum: Battle of the Smithsonian', 'Click']
#
# === Topic 27: earth, planet, face, humanity, fate ===
# ['Transformers: Age of Extinction', 'Mad Max: Fury Road', 'Zombieland', 'Now You See Me 2', 'Dawn of the Planet of the Apes', 'Star Trek Into Darkness', 'The Old Guard', 'They Live', 'Godzilla vs. Kong', 'Rise of the Planet of the Apes', 'Avengers: Infinity War', 'Avengers: Endgame', 'Star Trek', 'Rogue One: A Star Wars Story', 'The Cloverfield Paradox', 'WALL·E', 'Fantastic Four', 'Fantastic Four: Rise of the Silver Surfer', 'Pacific Rim', 'Jumanji: The Next Level']
#
# === Topic 28: drug, decides, detective, living, daughter ===
# ['The Girl with the Dragon Tattoo', 'The Girl with the Dragon Tattoo', 'The Substance', 'I Can Quit Whenever I Want', 'Dreams in the Witch House', 'The Girl Who Played with Fire', 'Searching', 'Inherent Vice']
#
# === Topic 29: future, super, inside, war, unexpected ===
# ['Terminator Salvation', 'The Fabelmans', 'RoboCop', 'Terminator: Dark Fate', 'Cars 3', 'The Matrix Reloaded', 'Transformers', 'Snowpiercer', 'THX 1138', 'Top Gun: Maverick', 'Kick-Ass', 'Top Gun', 'Terminator Genisys', 'I, Robot', 'The Circle', 'Real Steel', 'Terminator 3: Rise of the Machines']
#
# === Topic 30: true, named, adventure, human, beautiful ===
# ['Barbie', 'The Magic Flute', 'Frozen', 'Beauty and the Beast', 'Bambi', 'Aladdin', 'The Little Mermaid', 'The NeverEnding Story', 'Beauty and the Beast', 'Dragon Ball DAIMA', 'Fantasia', 'Wonder Woman']
#
# === Topic 31: girlfriend, relationship, falls, like, daughter ===
# ['Death Sentence', 'It Follows', 'Home Alone', 'Dead Ringers', 'Sweetie', 'A Star Is Born', 'A Walk to Remember', 'Shaun of the Dead', 'Road Trip', '17 Again', 'Match Point', 'Ted', 'Trainspotting', 'Bananas', 'T2 Trainspotting', "The Guy Who Didn't Like Musicals", 'The 40 Year Old Virgin', 'Between Two Ferns: The Movie', 'Shame', 'Disturbia']
#
# === Topic 32: time, terrifying, sent, group, race ===
# ['Twelve Monkeys', 'Contagion', 'Looper', 'Final Destination 5', 'Angels & Demons', 'In Time', 'Shivers', "Fermat's Room", 'Inferno']
#
# === Topic 33: husband, wife, daughter, revenge, game ===
# ['I Still Know What You Did Last Summer', 'Pierrot le Fou', 'Manhattan Murder Mystery', 'Three Colours: Blue', 'Corpse Bride', 'Diabolique', 'The Decameron', 'The Shrouds', 'A Deadly Invitation', 'I Stand Alone', 'Possession', 'A Bay of Blood', 'Ready or Not', 'Dial M for Murder', 'The Last of Sheila', 'Kill Bill: Vol. 2']
#
# === Topic 34: bond, agent, game, mission, known ===
# ['Goldfinger', 'Dr. No', 'Megamind', 'Bullet Train', 'From Russia with Love', 'Batman', 'Quantum of Solace', 'Casino Royale']
#
# === Topic 35: space, planet, crew, inside, team ===
# ['Prometheus', 'Interstellar', 'Everest', 'The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Avatar', 'Star Trek Beyond', 'Alien: Covenant', '2001: A Space Odyssey', 'Atlantis: The Lost Empire', 'Kong: Skull Island', 'Stagecoach', 'First Man', 'Alien', 'Dune', 'Alien: Romulus']
#
# === Topic 36: terrifying, earth, escape, small, team ===
# ['Super 8', 'Ghostbusters', 'Dawn of the Dead', '[REC]', 'Resident Evil: Apocalypse', 'One Cut of the Dead', 'Killer Klowns from Outer Space', 'Train to Busan', '28 Days Later']
#
# === Topic 37: killer, gang, set, force, revenge ===
# ['Watchmen', 'Thanksgiving', 'Fear Street: 1994', 'The Blair Witch Project', 'The Revenant', 'Scream 2', 'Mad Max', 'Scream 3', 'Jigsaw', 'Assault on Precinct 13', 'Scream 4', 'Insomnia', 'Scream', 'Texas Chainsaw Massacre', 'Scream']
#
# === Topic 38: group, trapped, terrifying, accident, game ===
# ['Fear Street: 1978', 'The Dark Tower', 'Turbo Kid', 'Circle', 'The Place', 'The New Mutants', 'Gretel & Hansel', 'Cabin Fever', 'Night of the Living Dead', 'Demons', "Don't Breathe", 'The Evil Dead', 'Fear Street: 1666', 'Jumanji: Welcome to the Jungle', 'The Cabin in the Woods', 'Fantastic Four', 'The Strangers', 'Blair Witch', 'City of Ember', 'Monster House']
#
# === Topic 39: war, army, group, force, killing ===
# ['1917', 'Freaks Out', "Jodorowsky's Dune", 'Dunkirk', 'Tropic Thunder', 'Inglourious Basterds', 'All Quiet on the Western Front', 'Downfall', 'November', 'Lola', 'Salò, or the 120 Days of Sodom', 'Fascists on Mars']
#
# === Topic 40: friends, adventure, group, struggle, lost ===
# ['Breaking Surface', 'La Haine', 'Nope', 'Madagascar', 'And Then There Were None', 'The Texas Chain Saw Massacre', 'Deliverance', 'The Descent', 'Puss in Boots: The Last Wish', 'Bad Times at the El Royale', 'The Florida Project', 'Sin City: A Dame to Kill For', 'Requiem for a Dream', 'Frozen', 'Flow', 'Beverly Hills Chihuahua', 'Adrift', 'Crawl', 'The Fox and the Hound', 'Wrong Turn']
#
# === Topic 41: film, personal, events, story, ancient ===
# ['Loro 2', 'Rose Island', '8½', 'Box Office 3D: The Filmest of Films', 'Loro 1', 'The Great Beauty', 'Beau Travail', 'The 2 Usual Idiots', 'Super Fantozzi', 'The Hand of God', 'Baggio: The Divine Ponytail']
#
# === Topic 42: mother, long, great, relationship, army ===
# ['Shakespeare in Love', 'Incendies', 'Mamma Mia!', 'A Christmas Tale', 'Barbie in the 12 Dancing Princesses', 'Priscilla']
#
# === Topic 43: brother, bond, family, seemingly, unexpected ===
# ['Hell or High Water', 'The Village', 'Horrible Bosses 2', 'The Fisher King', 'The Power of the Dog', 'Punch-Drunk Love', 'The Celebration', 'Sense8: Happy F*cking New Year', 'The Rich, the Pauper and the Butler', 'High and Low', 'Ju-on: The Curse 2', 'Just Believe', 'The Prince of Egypt', 'The Night of the Hunter', 'The Visit', 'Horrible Bosses', 'Parasite', 'The Pursuit of Happyness', "We're the Millers", 'Five Easy Pieces']
#
# === Topic 44: lives, dr, children, try, goes ===
# ['Pet Sematary', 'The Monitor', 'Out of Season', 'Forever Young']
#
# === Topic 45: far, away, set, destroy, real ===
# ['Shrek', 'Shrek Forever After', 'Shrek the Third', 'Shrek 2']
#
# === Topic 46: war, named, quest, return, sets ===
# ['Furiosa: A Mad Max Saga', 'Life of Pi', 'Kung Fu Panda', 'The Mummy: Tomb of the Dragon Emperor', 'Gran Torino', 'Ice Age', 'Black Panther: Wakanda Forever', 'Snow Leopard', 'Ice Age: The Meltdown', 'The Jungle Book', 'Alvin and the Chipmunks', 'Lilo & Stitch', 'Ice Age: Continental Drift', 'Mad Max 2', 'Dumbo']
#
# === Topic 47: turn, face, known, car, determined ===
# ['It', "Watch Out, We're Mad", 'It', "Don't Worry Darling", 'RIDE - Riders']
#
# === Topic 48: school, room, student, drug, high ===
# ['Silence', 'School of Rock', 'Dead Poets Society', 'Late Night with the Devil', 'Picnic at Hanging Rock', 'The Tenant', 'Klaus', 'The Raid', 'The Simpsons Movie', 'Primal Fear', 'Panic Room', 'Phenomena', 'Knowing', 'Suspiria', 'The Trial', 'I Can Quit Whenever I Want 3: Ad Honorem', 'Bad Tales', 'Easy A', 'Ju-on: The Curse', 'The Holdovers']
#
# === Topic 49: little, killer, game, series, daughter ===
# ['Halloween Kills', 'The Black Phone', "You're Next", 'Fantozzi 2000 - The Cloning', 'Goosebumps', 'This Is the End', 'Game Night', 'A Nightmare on Elm Street', 'Terrifier 2', 'Saw 3D', 'This Must Be the Place', 'A Nightmare on Elm Street', "A Nightmare on Elm Street Part 2: Freddy's Revenge", 'The Grudge 3', 'Krampus', "Jacob's Ladder", "Chip 'n Dale: Rescue Rangers", 'What Dreams May Come']
#
# === Topic 50: lost, boy, father, home, brother ===
# ['Nebraska', 'Skinamarink', 'The Judge', 'Better Watch Out', 'Manchester by the Sea', 'Paris, Texas', 'Inside Out', 'Lion', 'The Secret of Moonacre', 'Inkheart', 'Inferno', 'Due Date', 'Ju-on: The Beginning of the End', 'Sinister 2', 'Sinners']
#
# === Topic 51: band, daughter, car, unexpected, relationship ===
# ['Ford v Ferrari', 'Hannah Montana: The Movie', 'Titanic', 'The Idea of You', 'Serena', 'Big Eyes', 'Bohemian Rhapsody', 'Mean Girls', '21 Grams', 'Annie Hall', 'Father of the Bride', 'The Favourite', 'Father of the Bride', 'Inside Llewyn Davis', 'The Royal Tenenbaums', 'Finding Dory']
#
# === Topic 52: change, brother, government, lives, husband ===
# ['The Hunger Games: Mockingjay – Part 1', 'The Hunger Games', 'The Hunger Games: Mockingjay – Part 2', 'The Hunger Games: Catching Fire', 'Troy', 'The Hunger Games: The Ballad of Songbirds & Snakes']
#
# === Topic 53: control, day, agent, accident, american ===
# ['Black Mirror: Smithereens']
#
# === Topic 54: killing, room, night, day, killer ===
# ['Nostalgia', 'Dead Silence', 'Zoolander', 'Hugo', 'The Invisible Witness', 'Blood and Black Lace', 'The Guest Room', 'Run Lola Run', 'Four Flies on Grey Velvet', 'Tetsuo: The Iron Man', 'Glorious', 'Death Proof', 'Naked', 'Creep', 'Zoolander 2', 'El Mariachi', 'Body Double']
#
# === Topic 55: mission, agent, team, super, enemy ===
# ['The Silence of the Lambs', 'Ant-Man', 'Red Dragon', 'Spider-Man: Far From Home', 'Mission: Impossible – Rogue Nation', 'Hannibal', 'Mission: Impossible – Ghost Protocol', 'Ant-Man and the Wasp', 'Mission: Impossible – Fallout', 'Rush', 'Ant-Man and the Wasp: Quantumania', 'Mission: Impossible – Dead Reckoning', 'Alphaville', 'I Can Quit Whenever I Want 2: Masterclass', 'Spider-Man: Into the Spider-Verse', 'The Avengers', 'Mission: Impossible III', 'Mission: Impossible II', 'Venom', 'Mission: Impossible']
#
# === Topic 56: brother, gang, crew, revenge, determined ===
# ['Die Hard With a Vengeance', 'American History X', 'The Fast and the Furious', 'Fast Five', 'Drive', 'Fast & Furious 6', 'Fast & Furious', 'Furious 7', 'F9', 'Fast X']
#
# === Topic 57: dr, ancient, search, led, rescue ===
# ['Loving Vincent', 'Night at the Museum', 'Meet the Robinsons', 'Indiana Jones and the Kingdom of the Crystal Skull', 'Indiana Jones and the Last Crusade', 'Indiana Jones and the Dial of Destiny', 'Raiders of the Lost Ark', 'National Treasure', 'The Monuments Men', 'Oz the Great and Powerful', 'Indiana Jones and the Temple of Doom']
#
# === Topic 58: earth, destroy, quest, ancient, battle ===
# ['Come and See', 'Dragon Ball Super: Broly', 'The Hobbit: The Battle of the Five Armies', 'Thor', 'How to Train Your Dragon 2', 'The Hobbit: An Unexpected Journey', 'How to Train Your Dragon: The Hidden World', 'The Lord of the Rings: The Fellowship of the Ring', 'Dragon Ball Z: Battle of Gods', 'How to Train Your Dragon', 'Thor: The Dark World', 'Percy Jackson: Sea of Monsters', 'The Lord of the Rings: The Two Towers', 'The Sword in the Stone', 'Thor: Love and Thunder', 'The Last Temptation of Christ', "Dragon Ball Z: Resurrection 'F'", 'Thor: Ragnarok', 'Dune: Part Two', 'Shang-Chi and the Legend of the Ten Rings']
#
# === Topic 59: named, return, evil, london, human ===
# ['Garfield', 'Peter Pan', 'Tarzan', 'The Chronicles of Narnia: Prince Caspian', 'Garfield: A Tail of Two Kitties', 'Hook', 'The Black Cauldron']
#
# === Topic 60: york, company, forced, make, crew ===
# ["Madagascar 3: Europe's Most Wanted", 'The Wild', 'Madagascar: Escape 2 Africa', 'King Kong']
#
# === Topic 61: quest, makes, change, run, parents ===
# ['Humanist Vampire Seeking Consenting Suicidal Person', 'After We Fell', 'After We Collided', 'Black Swan', 'After Ever Happy', 'After Everything', 'The Twilight Saga: New Moon', 'The Twilight Saga: Eclipse', 'Persona', 'Sense8: Amor Vincit Omnia', 'Twilight', 'Red Riding Hood', 'After', 'The Twilight Saga: Breaking Dawn – Part 1']
#
# === Topic 62: years, begins, human, planet, couple ===
# ['Jurassic Park', 'The Vanishing', 'The Lost World: Jurassic Park', 'Dinosaur', 'Jurassic World', 'Jurassic World: Fallen Kingdom', 'Jurassic World Dominion']
#
# === Topic 63: planet, earth, race, humanity, space ===
# ['Elysium', 'Ad Astra', 'Children of Men', 'Planet of the Apes', 'The Mothman Prophecies', '2012', 'Planet of the Apes', 'Dune', 'Greenland']
#
# === Topic 64: crime, seeks, revenge, york, family ===
# ['The Godfather Part III', 'Adagio', 'The Godfather', 'John Wick: Chapter 2', 'The Crow', 'The Godfather Part II', 'John Wick']
#
# === Topic 65: sister, come, family, woman, determined ===
# ['Hop', 'Joyland', 'The Spiderwick Chronicles', 'Looney Tunes: Back in Action', 'The Super Mario Bros. Movie', 'Blue Jasmine', 'The Aristocats', 'Guardians of the Galaxy Vol. 2', 'Ratatouille', 'The Adventures of Priscilla, Queen of the Desert']
#
# === Topic 66: game, boy, world, room, high ===
# ['Charlie and the Chocolate Factory', 'Toy Story 4', 'The Lego Movie', 'eXistenZ', 'Pokémon Detective Pikachu', 'Ex Machina', 'The Three Caballeros', 'Cars 2', 'The Giver', 'Jumanji', 'Toy Story 3', 'The Last Mimzy', 'Primer', 'Shazam!', 'Onward', 'High School Musical', 'Toy Story 2', 'Toy Story', 'Choose or Die', 'Big Hero 6']
#
# === Topic 67: order, protect, army, forces, ancient ===
# ['The Twilight Saga: Breaking Dawn – Part 2', 'Blade', 'Blade II', 'Blade: Trinity', 'Dracula Untold']
#
# === Topic 68: wife, husband, little, couple, children ===
# ['Unfaithful', 'Mamma Mia! Here We Go Again', 'Ted 2', 'War of the Worlds', 'Extremely Wicked, Shockingly Evil and Vile', 'Gone Baby Gone', 'Meet the Fockers', 'Meet the Parents', 'Funny Games', 'Eyes Wide Shut', 'Mary Poppins', 'Cheaper by the Dozen', 'Where Am I Going?', "We Don't Live Here Anymore", 'The Shining', 'sex, lies, and videotape', 'Little Fockers', 'The Incredibles', 'Three Billboards Outside Ebbing, Missouri', 'No Way Out']
#
# === Topic 69: london, relationship, company, york, begins ===
# ['Black Mirror: Fifteen Million Merits', 'The Neon Demon', 'Pleasure', 'The Intern', 'The Devil Wears Prada', 'Brooklyn', 'The Outside', 'Cosmopolis', 'Last Night in Soho', 'A Cure for Wellness', 'Phantom Thread', 'The Internship', 'Funeral Parade of Roses']
#
# === Topic 70: powers, learns, powerful, end, school ===
# ['Harry Potter and the Order of the Phoenix', 'Harry Potter and the Goblet of Fire', 'Harry Potter and the Half-Blood Prince', 'Fantastic Beasts: The Secrets of Dumbledore', 'Pokémon the Movie: I Choose You!', 'Harry Potter and the Chamber of Secrets', 'Harry Potter and the Deathly Hallows: Part 2', "Harry Potter and the Philosopher's Stone", 'Harry Potter and the Deathly Hallows: Part 1']
#
# === Topic 71: bond, agent, space, mission, secret ===
# ['Die Another Day', 'Moonraker', 'Spectre', 'No Time to Die', 'Tomorrow Never Dies', 'Live and Let Die', 'A View to a Kill', 'Thunderball', 'Skyfall', 'The World Is Not Enough', 'For Your Eyes Only', 'The Living Daylights', 'The Spy Who Loved Me']
#
# === Topic 72: parents, things, attempt, high, face ===
# ['Back to the Future Part II', 'Back to the Future', 'High School Musical 2', 'The Perks of Being a Wallflower', 'Back to the Future Part III', 'Let It Be', 'Dazed and Confused', 'Moneyball']
#
# === Topic 73: film, real, man, accident, story ===
# ["The Sorcerer's Apprentice", 'Super Size Me', 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan', 'Awake', 'Sweeney Todd: The Demon Barber of Fleet Street', 'The King', 'A Couch in New York', 'Zelig', 'The Imaginarium of Doctor Parnassus', 'Green Book', 'Crimes and Misdemeanors', 'Citizen Kane', 'Bean', 'The Killing of a Sacred Deer', 'Unbreakable', 'Close-Up', 'The Big Lebowski', 'The Dam', 'Bedtime Stories', 'Ricky Gervais: Humanity']
#
# === Topic 74: film, killer, agent, murder, true ===
# ['Longlegs', 'Sinister', 'Wind River', 'The Apprentice', 'The Lincoln Lawyer', 'Captain Phillips']
#
# === Topic 75: couple, relationship, bond, american, girl ===
# ['Scott Pilgrim Takes Off', 'In the Mood for Love', 'The Sheltering Sky', 'West Side Story', 'Bride Wars', 'Hard Eight', 'Licorice Pizza', 'Coherence', 'Three Colours: Red', 'Closer', 'Sleuth', "I'm Thinking of Ending Things", 'Last Tango in Paris', 'Brain Drain', 'The Lobster', 'The Hangover Part III', 'Chungking Express', 'Casablanca', 'Mr. & Mrs. Smith', 'Before Midnight']
#
# === Topic 76: doctor, room, man, wife, discover ===
# ['Unknown', 'Spider', 'Vertigo', 'Young Frankenstein', 'Frankenstein', 'Victor Frankenstein', '1408', "Mary Shelley's Frankenstein", 'Oldboy', 'The Rocky Horror Picture Show', 'Doctor Strange in the Multiverse of Madness', 'The Brood', "The Cat o' Nine Tails", 'Hulk', 'Invasion of the Body Snatchers']
#
# === Topic 77: husband, father, home, mother, remote ===
# ['Leave the World Behind', 'Knock Knock', 'Roma', 'Ghostland', 'The Man Who Knew Too Much', 'Family Plot', 'No Escape', "Lemony Snicket's A Series of Unfortunate Events", 'The Purge', 'Knock at the Cabin', 'All the Money in the World', 'Room', 'Identity', 'Taken 2', 'From Dusk Till Dawn', '12 Angry Men', 'Angst', 'Stolen', 'Django Unchained', 'Monolith']
#
# === Topic 78: woman, meets, girl, story, determined ===
# ['Compulsion', 'Coraline', 'Collateral Beauty', "Pan's Labyrinth", 'The Graduate', 'Gone with the Wind', 'Evil Dead II', 'The Sixth Sense', 'Anomalisa', 'Next Door', 'Biutiful', 'Insidious: Chapter 3', '50 First Dates', 'Doctor Sleep', 'Evil Dead', 'The Watchers', 'Enea', 'The Gift', 'Under the Silver Lake', 'Cronos']
#
# === Topic 79: war, world, adventure, unexpected, earth ===
# ['Oppenheimer', 'Captain Marvel', 'Iron Man', 'Captain America: The Winter Soldier', 'Iron Man 2', 'Captain America: Civil War', 'Iron Man 3', 'Captain America: The First Avenger', 'Avengers: Age of Ultron']
#
# === Topic 80: london, adventure, great, heart, island ===
# ['Mickey, Donald, Goofy: The Three Musketeers', 'Fun and Fancy Free', 'The King of Comedy', 'Catwoman', 'Mickey 17', "Mickey's Twice Upon a Christmas", 'Flushed Away', 'Superhero Movie', 'The Greatest Showman']
#
# === Topic 81: mission, earth, war, inside, struggle ===
# ['American Sniper', 'Buried', 'Oblivion', 'The Martian']
#
# === Topic 82: detective, murder, room, crime, turns ===
# ['Dark Shadows', 'Army of Darkness', 'Cemetery Man', 'Murder on the Orient Express', 'Scrooged', 'Nosferatu', 'Clue', 'A Haunting in Venice', 'Four Rooms', 'The Innkeepers', 'Death on the Nile', 'The ABC Murders', 'Midnight in Paris', 'The Usual Suspects', 'Sherlock: The Abominable Bride']
#
# === Topic 83: friends, best, finally, york, try ===
# ['Monsters University', 'Past Lives', 'The Big Chill', 'Three Identical Strangers', 'Friends: The Reunion', 'Last Vegas', "The World's End", 'My Friends', 'The Hangover', "There's No Place Like Home"]
#
# === Topic 84: london, best, seeks, seemingly, following ===
# ['Following', 'Naked', 'Birdman or (The Unexpected Virtue of Ignorance)', 'A Single Man']
#
# === Topic 85: agent, mission, super, team, detective ===
# ['The Pink Panther 2', 'Thunderbolts*', 'Scanners', 'Lethal Weapon 2', 'Live Free or Die Hard', 'Project Power', 'Despicable Me 2', 'Kingsman: The Secret Service', 'The Interview', 'Repo Man', 'Source Code', 'Argo', 'Sherlock Holmes', 'Sherlock Holmes: A Game of Shadows', 'Bombshell', 'Inside Man', 'Ronin', "Assassin's Creed", 'Akira', 'Apocalypse Now']
#
# === Topic 86: father, brother, best, husband, taken ===
# ['The Lion King', 'Black Panther', 'Challengers', 'The Lion King']
#
# === Topic 87: earth, space, father, boy, discovers ===
# ['Guardians of the Galaxy', 'Percy Jackson & the Olympians: The Lightning Thief', 'Sky High', 'Man of Steel', 'After Earth', 'Treasure Planet', 'Despicable Me', 'The Theory of Everything']
#
# === Topic 88: planet, sent, space, doctor, crew ===
# ['Solaris', 'Solaris', 'Stereo (Tile 3B of a CAEE Educational Mosaic)', 'The Similars', 'Total Recall']
#
# === Topic 89: wife, gets, drug, police, ex ===
# ['The Killing', 'Bridget Jones: The Edge of Reason', 'Walk the Line', 'Spiral: From the Book of Saw', 'The Gentlemen', 'Presumed Innocent', 'Lethal Weapon', 'Fargo', 'Miami Vice', 'The Shawshank Redemption', 'The Laundromat', 'The Full Monty', 'Super Size Me 2: Holy Chicken!', 'Bicycle Thieves', "Ocean's Eleven", 'Marnie', "Ocean's Thirteen", 'Need for Speed', 'Three Colours: White', "Ocean's Twelve"]
#
# === Topic 90: island, sister, wife, small, boy ===
# ['The Boy and the Heron', 'Bāhubali: The Beginning', 'Ju-on: The Final Curse', 'Tokyo Story', 'Departures', 'Sadako vs. Kayako', 'Demons', 'Tetsuo: The Bullet Man', 'Kwaidan', 'Drive My Car', 'Love Life', 'The Handmaiden', 'Don Juan', 'Isle of Dogs', 'Lost in Translation', 'Godzilla']
#
# === Topic 91: struggle, personal, student, sister, turns ===
# ['Maps to the Stars', 'La La Land', 'Marriage Story', 'Hail, Caesar!', 'The Social Network', '21 & Over', 'Raw', 'Us', 'Melancholia', 'Into the Wild', 'The Hangover Part II', 'Triangle of Sadness', 'Red Eye']
#
# === Topic 92: army, face, forces, evil, dark ===
# ['Star Wars: Episode I – The Phantom Menace', 'Star Wars: Episode II –\xa0Attack of the Clones', 'Star Wars: The Clone Wars', 'Star Wars: Episode III –\xa0Revenge of the Sith']
#
# === Topic 93: rescue, evil, power, space, dark ===
# ['Spaceballs', 'Return of the Jedi', 'Star Wars', 'Star Wars: The Rise of Skywalker', 'Star Wars: The Force Awakens', 'Solo: A Star Wars Story', 'The Empire Strikes Back']
#
# === Topic 94: small, war, makes, falls, return ===
# ['BARDO, False Chronicle of a Handful of Truths', 'Fantozzi: White Collar Blues', 'The Traitor', 'Welcome Mr. President!', 'The Commander', 'Women Vs Men', "The Devil's Backbone", 'The Night Before the Exams Today', 'Welcome to the South', 'Luca', 'Close Enemies', 'The Night Before the Exams']
#
# === Topic 95: village, beautiful, stop, story, day ===
# ['Sleeping Beauty', 'Snow White and the Seven Dwarfs', 'Hot Fuzz', 'Anora', 'Maleficent', 'The Mummy', 'Wicked', 'The Wizard of Oz', 'The Last Airbender']
#
# === Topic 96: night, named, leading, little, killing ===
# ['Terrifier', 'Scary Stories to Tell in the Dark', 'Halloween', 'Halloween', 'Monsters, Inc.', 'Halloween']
#
# === Topic 97: village, things, evil, home, house ===
# ['Scooby-Doo', 'Ju-On: Origins', 'Insidious: Chapter 2', 'The Fog', 'The Conjuring: The Devil Made Me Do It', 'Insidious', 'Paranormal Activity', 'The Brothers Grimm', 'Hansel & Gretel: Witch Hunters', 'The Haunting', 'Lights Out', 'Viy', 'Mr. Devil', 'Annabelle: Creation', 'The Conjuring', 'They Cloned Tyrone', 'Scary Movie 5', 'Candyman', 'Paranormal Activity 2', 'Fright Night']
#
# === Topic 98: car, order, gets, discovers, accident ===
# ['Soul', 'Ghost Rider', 'Cars', 'The Dead Zone']
#
# === Topic 99: fight, friend, battle, determined, seeks ===
# ['Rocky III', 'Creed', 'Creed III', 'Rocky IV', 'Rocky II']

# %%
df_test = pd.read_csv('ml_data/train.csv')
embeddings_test = joblib.load("ml_data/train_emb.pkl")

# %%
labels_test = kmeans.predict(embeddings_test)

df_test["Topic"] = labels_test
df_test["Topic_Name"] = [
    ", ".join(filtered_cluster_keywords[label])
    for label in labels_test
]

for topic in sorted(df_test["Topic"].unique()):
    print(f"\n=== Topic {topic}: {', '.join(filtered_cluster_keywords[topic])} ===")
    print(df_test[df_test["Topic"] == topic]['Title'].to_list())
# Out:
# === Topic 0: arctic, ice, frozen, warming, prehistoric ===
# ['Madagascar: Escape 2 Africa', 'The Thing', 'Snowpiercer']
#
# === Topic 1: life, man, new, world, happiness ===
# ['Yes Man', 'Following', 'Collateral Beauty', '21 & Over', 'Shaun of the Dead', 'Locke', 'A Single Man']
#
# === Topic 5: father, man, revenge, murdered, killed ===
# ['The Northman', 'The Power of the Dog', 'The Godfather', 'Furious 7', "Lemony Snicket's A Series of Unfortunate Events", 'I Stand Alone']
#
# === Topic 6: life, world, wife, paris, new ===
# ['21 Grams', 'Buried', "The Guy Who Didn't Like Musicals", 'Paul', 'Dune: Part Two']
#
# === Topic 7: prison, inmates, jail, released, sentence ===
# ['Ant-Man and the Wasp', 'I Can Quit Whenever I Want 3: Ad Honorem', 'Escape from New York', 'The Shawshank Redemption', 'Oldboy']
#
# === Topic 8: ghost, haunted, house, ghosts, paranormal ===
# ['Ju-On: Origins', 'Insidious: Chapter 2', 'Paranormal Activity', 'The Haunting', 'The Murmuring', 'Scary Stories to Tell in the Dark', 'I Am the Pretty Thing That Lives in the House', 'The Conjuring', 'Scary Movie 5', 'Annabelle Comes Home', 'The Grudge', 'The Innkeepers', 'Ju-on: The Grudge 2', 'Annabelle', 'Insidious: The Last Key', 'Hush', 'Ghostbusters']
#
# === Topic 10: christmas, holidays, new, holiday, family ===
# ['Hannah Montana: The Movie', 'Goosebumps']
#
# === Topic 12: samurai, zatoichi, japan, ronin, japanese ===
# ['Tetsuo II: Body Hammer', 'Demons', 'Tetsuo: The Bullet Man', 'Kwaidan']
#
# === Topic 15: film, images, camera, frame, image ===
# ['Zorns Lemma']
#
# === Topic 19: adventure, summer, island, world, pokémon ===
# ['The Super Mario Bros. Movie', 'Us', 'Ice Age: The Meltdown', 'Lilo & Stitch']
#
# === Topic 21: teacher, school, students, teachers, student ===
# ['Dead Poets Society', 'Phenomena', 'Ju-on: The Beginning of the End', 'Ju-on: The Curse', 'The Holdovers', 'Bad Teacher', 'The Hunt', 'Battle Royale', 'The Wave', 'Another Round']
#
# === Topic 23: gangster, painter, research, inspector, assassin ===
# ['Angel Heart', 'Now You See Me']
#
# === Topic 25: throne, shakespeare, england, sir, medieval ===
# ["Assassin's Creed", 'Napoleon', 'The Hunger Games: Mockingjay – Part 1', 'Robin Hood', 'Conclave', 'The Seventh Seal', 'The Last Temptation of Christ']
#
# === Topic 26: halloween, night, friends, sorority, scream ===
# ['It', 'Ghostbusters', 'It', 'Demons', 'Terrifier', 'Monster House']
#
# === Topic 27: actress, director, comedy, actor, hollywood ===
# ['Marriage Story', 'Adaptation.', 'Crimes and Misdemeanors', 'Mulholland Drive', 'Don Juan', 'Enemy']
#
# === Topic 28: racing, race, car, racer, skateboarding ===
# ['Ford v Ferrari', "Watch Out, We're Mad", 'Cars 3', 'Cars 2', 'Drive', 'Rush', 'RIDE - Riders', 'Cars', 'Need for Speed']
#
# === Topic 29: crime, cop, criminal, police, gossip ===
# ['The Killing', 'The Silence of the Lambs', 'Mr. & Mrs. Smith', 'Nightcrawler']
#
# === Topic 30: horror, film, movie, films, movies ===
# ['Knife+Heart', 'Scary Movie 3', 'The Strangers', 'Scream 3', 'Scream']
#
# === Topic 31: young, woman, girl, world, village ===
# ['10 Cloverfield Lane', 'Spirited Away', 'Tomb Raider']
#
# === Topic 32: suicide, woman, death, life, terminally ===
# ['Bird Box', 'Je Tu Il Elle', 'Colossal']
#
# === Topic 34: pirate, pirates, captain, ship, navy ===
# ["Pirates of the Caribbean: At World's End", "Pirates of the Caribbean: Dead Man's Chest", 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Pirates of the Caribbean: Dead Men Tell No Tales', 'Captain Phillips', 'Ice Age: Continental Drift']
#
# === Topic 37: married, marriage, husband, wife, wedding ===
# ['Unfaithful', 'Serena', '50 First Dates', 'Big Eyes', 'Father of the Bride', 'Father of the Bride', "We Don't Live Here Anymore", 'Priscilla']
#
# === Topic 39: family, brother, home, father, dad ===
# ['Halloween Kills', 'Home Alone', '17 Again', 'Little Fockers', 'Split', "Chip 'n Dale: Rescue Rangers"]
#
# === Topic 40: moon, lunar, astronauts, astronaut, nasa ===
# ['Avatar', '2001: A Space Odyssey', 'First Man']
#
# === Topic 41: holmes, watson, detective, dr, sir ===
# ['Sherlock Holmes', 'Sherlock: The Abominable Bride']
#
# === Topic 42: hell, devil, satan, demon, demons ===
# ['Faust', 'Deliver Us from Evil', 'Hellboy']
#
# === Topic 44: detective, police, murder, investigator, inspector ===
# ['The Nice Guys', 'Rear Window', 'Vertigo', 'Gone Baby Gone', 'Gone Girl', 'Murder on the Orient Express', 'The Fate of the Furious', 'Sinister', 'In the Mouth of Madness', 'A Haunting in Venice', 'The Conversation', 'Twilight', 'Cure', 'Knives Out', 'Jack Reacher', 'The ABC Murders', 'Glass Onion', 'Inherent Vice']
#
# === Topic 45: sister, sisters, family, mother, twin ===
# ['Titanic', 'The Spiderwick Chronicles', 'The Favourite', 'Barbie in the 12 Dancing Princesses', 'The Royal Tenenbaums', 'Finding Dory', '27 Dresses']
#
# === Topic 46: pilot, pilots, war, air, fighter ===
# ['Apocalypse Now', 'Top Gun: Maverick', 'Top Gun', 'Edge of Tomorrow']
#
# === Topic 47: black, rights, african, racial, american ===
# ['Shadow of Fire', 'The Trial of the Chicago 7', 'Judas and the Black Messiah', 'American Fiction', 'Hunger']
#
# === Topic 50: killer, serial, murder, murderer, police ===
# ["One Flew Over the Cuckoo's Nest", 'Rope', 'Red Dragon', 'Friday the 13th', 'Saw II', 'Mr. Devil', 'The Trial', 'Wind River', 'The Bird with the Crystal Plumage', 'Adolescence', 'Insomnia', 'Scream', 'Memories of Murder', 'Se7en']
#
# === Topic 51: duck, goofy, bugs, cartoon, pig ===
# ['Looney Tunes: Back in Action', 'Gremlins', 'The Greatest Showman', 'Dumbo']
#
# === Topic 52: musical, broadway, songs, music, winning ===
# ['Sweeney Todd: The Demon Barber of Fleet Street', 'Annie Hall', 'Fantasia']
#
# === Topic 53: memory, remember, memories, amnesia, past ===
# ['Total Recall']
#
# === Topic 56: woman, wakes, blind, visions, deaf ===
# ['Inside', 'Smile', 'Klute', 'Good Bye, Lenin!', 'Creep 2']
#
# === Topic 58: doctor, hospital, patients, dr, patient ===
# ['Frantic', 'Woman in the Dunes', 'Awake', 'Solaris', 'The Killing of a Sacred Deer', 'Shivers', 'Planet Terror', 'Wild Strawberries', 'Invasion of the Body Snatchers']
#
# === Topic 59: el, spanish, josé, mexican, mexico ===
# ['Nostalgia']
#
# === Topic 60: cinema, film, films, filmmakers, director ===
# ['The Fabelmans', 'QT8: The First Eight', 'Babylon']
#
# === Topic 61: year, old, teenager, age, life ===
# ['The Giver', 'Slumdog Millionaire']
#
# === Topic 63: wedding, marriage, married, couple, honeymoon ===
# ['In the Mood for Love', 'Bride Wars', 'Melancholia', 'The Hangover Part III', 'The Twilight Saga: Breaking Dawn – Part 1', 'mother!']
#
# === Topic 64: christmas, santa, scrooge, holiday, reindeer ===
# ['The Nightmare Before Christmas', 'The Three Caballeros', 'A Christmas Carol', 'Winnie the Pooh: A Very Merry Pooh Year', 'Red One', 'Krampus', 'The Muppet Christmas Carol', 'The Santa Claus Gang', "FX's A Christmas Carol"]
#
# === Topic 65: fu, kung, martial, shaolin, arts ===
# ['Kung Fu Panda']
#
# === Topic 66: war, vietnam, soldier, soldiers, army ===
# ['The Shape of Water', 'Tropic Thunder', 'V for Vendetta', 'Da 5 Bloods']
#
# === Topic 67: vampire, vampires, dracula, blood, transylvania ===
# ['Humanist Vampire Seeking Consenting Suicidal Person', 'Dark Shadows', 'The Twilight Saga: Breaking Dawn – Part 2', "Bram Stoker's Dracula", 'The Twilight Saga: New Moon', 'The Twilight Saga: Eclipse', 'Nosferatu', 'Rabid', 'Blade', 'Fright Night', 'Blade II', 'Twilight', 'Nosferatu', 'Blade: Trinity', 'Dracula Untold']
#
# === Topic 68: murder, killer, detective, murderer, woman ===
# ['Gosford Park', 'Blood and Black Lace', 'Diabolique', 'Decision to Leave', 'Dressed to Kill', 'A Deadly Invitation', 'Anatomy of a Fall', 'Basic Instinct', 'A Bay of Blood', 'Angst', 'The Nile Hilton Incident']
#
# === Topic 70: italy, war, italian, film, fascist ===
# ['The Sun Will Rise']
#
# === Topic 71: cats, mouse, mice, cool, game ===
# ['Garfield', 'Catwoman', 'Garfield: A Tail of Two Kitties', 'The Aristocats']
#
# === Topic 72: ancient, child, cursed, children, demonic ===
# ['Evil Dead Rise', 'Enea', 'Lights Out', 'Bad Tales', 'Paranormal Activity 2', 'The Mummy']
#
# === Topic 73: evil, universe, earth, world, power ===
# ['Guardians of the Galaxy', 'Spaceballs', 'Return of the Jedi', 'The Old Guard', 'Despicable Me 2', 'Percy Jackson & the Olympians: The Lightning Thief', 'Star Wars: Episode I – The Phantom Menace', 'The Lego Movie', 'Star Wars: The Rise of Skywalker', 'After Earth', 'Fantastic Four', 'Solo: A Star Wars Story', 'The Empire Strikes Back', 'Green Lantern', 'Batman', 'Neon Genesis Evangelion: The End of Evangelion', 'Superhero Movie', 'Despicable Me', 'Thor: The Dark World', 'Star Wars: The Clone Wars', 'Venom', 'Mad Max Beyond Thunderdome', 'Star Wars: Episode III –\xa0Revenge of the Sith', 'Logan', 'Divergent', 'They Call Me Jeeg', 'Mr. Nobody', 'Venom: Let There Be Carnage']
#
# === Topic 74: tokyo, manga, school, japanese, girl ===
# ['Okja']
#
# === Topic 75: dead, corpse, death, tomb, burial ===
# ['Army of Darkness', 'The Trouble with Harry', 'Evil Dead II', 'Cemetery Man', 'Cronos', 'Corpse Bride', 'Final Destination 5', "Child's Play", 'Jigsaw']
#
# === Topic 76: flight, plane, passengers, pilot, aircraft ===
# ['Airplane!', 'Red Eye']
#
# === Topic 77: virginity, senior, prom, relive, losing ===
# ['Premature']
#
# === Topic 78: pregnant, baby, pregnancy, child, abortion ===
# ['Mamma Mia! Here We Go Again', 'Ted 2', 'Children of Men']
#
# === Topic 79: time, returns, years, past, earth ===
# ['Harry Potter and the Order of the Phoenix', 'Back to the Future Part II', 'Back to the Future', 'Fantozzi 2000 - The Cloning', 'Blade Runner', 'Back to the Future Part III', 'T2 Trainspotting', 'Saw III', 'Gravity', 'Midnight in Paris']
#
# === Topic 80: arc, throne, england, 15th, heir ===
# ['The King']
#
# === Topic 82: bugs, spider, creature, creatures, giant ===
# ['Naked Lunch', 'Saw', 'Fantastic Beasts and Where to Find Them']
#
# === Topic 83: revenge, woman, vengeance, assassin, served ===
# ['Kill Bill: Vol. 1', 'The Quick and the Dead', 'Lucy', 'Haywire', 'Black Widow', 'Promising Young Woman']
#
# === Topic 84: jazz, blues, music, musicians, musician ===
# ['Soul', 'Walk the Line', 'Green Book']
#
# === Topic 86: life, story, portrait, documentary, icon ===
# ['Zelig', 'Bubba Ho-tep', 'Inside Llewyn Davis', 'The Theory of Everything']
#
# === Topic 87: woods, deer, village, cabin, forests ===
# ['Nope', 'Gretel & Hansel', 'The Watchers', 'The Brothers Grimm', 'The Evil Dead', 'The Cabin in the Woods', 'Blair Witch', 'Happy Death Day 2U']
#
# === Topic 88: godzilla, earth, monster, giant, japan ===
# ['Godzilla vs. Kong', 'Avengers: Endgame', 'Godzilla: King of the Monsters', 'Godzilla']
#
# === Topic 89: family, home, families, children, generations ===
# ['I Hate Summer', 'Hell or High Water', 'Sinister 2', 'Minari', 'The Witch', 'Speak No Evil', 'A History of Violence', 'Death at a Funeral', "There's No Place Like Home"]
#
# === Topic 90: film, short, directed, movie, films ===
# ['Box Office 3D: The Filmest of Films', 'The 2 Usual Idiots']
#
# === Topic 91: teenagers, teenage, boys, teens, teen ===
# ['Turbo Kid', 'Fear Street: 1994', "Don't Breathe", 'The Night of the Hunter', 'A Nightmare on Elm Street', 'Final Destination', 'Salò, or the 120 Days of Sodom', 'Leatherface', 'Natural Born Killers', 'I Know What You Did Last Summer']
#
# === Topic 95: woman, night, man, hotel, romance ===
# ['Before Sunrise', 'Barbarian', 'The Tourist', "I'm Thinking of Ending Things", 'Last Tango in Paris', 'The Lobster', 'La Notte', 'Lost in Translation']
#
# === Topic 96: year, old, girl, 16, mother ===
# ['Pleasure', 'Inside Out', 'Raw', 'Turning Red', 'Cam', 'Lady Bird', 'Carrie', 'A Short Film About Love']
#
# === Topic 97: agent, spy, cia, secret, agents ===
# ['Lethal Weapon 2', 'Goldfinger', 'Kingsman: The Secret Service', 'Repo Man', 'Ronin', 'Sicario: Day of the Soldado', 'What a Beautiful Day', 'Spy Hard', 'The Avengers', 'Mission: Impossible II', 'Mission: Impossible', 'Total Recall', 'Body of Lies', 'Sicario', 'Spy Kids: Armageddon', 'Machete Kills', 'The Gray Man']
#
# === Topic 100: mother, family, maría, sisters, spain ===
# ['The Water', 'Blue Jasmine']
#
# === Topic 103: shark, sharks, fish, whale, sea ===
# ['Jaws', 'Godzilla', 'Luca', 'Finding Nemo']
#
# === Topic 105: school, girls, high, students, graduation ===
# ['Picnic at Hanging Rock', 'The Beguiled']
#
# === Topic 106: gang, gangs, brothers, brother, biker ===
# ["You're Next", 'Adagio', 'Avatar: The Way of Water', 'Attack the Block', 'Savages']
#
# === Topic 108: couple, house, home, family, tenants ===
# ['Knock Knock', 'The Sheltering Sky', "Rosemary's Baby", 'Manhattan Murder Mystery', 'Ju-on: The Curse 2', 'The Holiday', 'Neighbors']
#
# === Topic 112: encountered, skilled, assassin, performance, driver ===
# ['The Fast and the Furious', 'F9', 'Fast X']
#
# === Topic 113: college, sorority, fraternity, campus, school ===
# ['Black Christmas', 'Easy A']
#
# === Topic 115: magic, elaborate, mr, conceal, balancing ===
# ['The Prestige']
#
# === Topic 118: virus, quarantine, infected, infection, cameraman ===
# ['[REC]']
#
# === Topic 121: robot, punk, fantastical, division, therapist ===
# ['Fight Club', 'Big Hero 6']
#
# === Topic 122: earth, planet, space, universe, mankind ===
# ['Prometheus', 'Dawn of the Planet of the Apes', 'Star Trek Into Darkness', 'Elysium', 'Star Trek', 'The Cloverfield Paradox', 'Ad Astra', 'Star Wars: Episode II –\xa0Attack of the Clones', 'Star Trek Beyond', "Don't Look Up", 'Treasure Planet', '2012', 'Armageddon', 'Dune', 'Dune', 'Greenland']
#
# === Topic 123: ripper, life, doc, liar, family ===
# ['A Star Is Born', 'Blow Out', 'Pirates of the Caribbean: On Stranger Tides', "Don't Worry Darling", 'Oblivion', 'The Shining']
#
# === Topic 124: istanbul, turkey, kurdish, turkish, village ===
# ['The Dam']
#
# === Topic 126: story, woman, romantic, romance, life ===
# ['Licorice Pizza', 'Moonlight', 'Closer']
#
# === Topic 127: darkness, nightmare, nightmares, horror, night ===
# ['The Dark Tower', 'Insidious', 'The Mothman Prophecies', 'Suspiria']
#
# === Topic 128: indians, warrior, tribe, apache, indian ===
# ['Bāhubali 2: The Conclusion', 'Indiana Jones and the Temple of Doom', 'Mad Max 2']
#
# === Topic 129: são, brazil, joão, lisbon, life ===
# ['Bicycle Thieves']
#
# === Topic 132: virus, infected, pandemic, quarantine, survivors ===
# ['Contagion', 'This Is the End', 'Final Destination 3', 'Final Destination 2', 'Cabin Fever', '28 Weeks Later', '28 Days Later', 'Harry Potter and the Deathly Hallows: Part 1']
#
# === Topic 133: hero, brick, brien, martial, tank ===
# ['Citizen Kane']
#
# === Topic 135: gangster, mafia, drug, gang, crime ===
# ['The Legend of Al, John and Jack', 'The Departed', 'The Godfather Part III', 'Seven Psychopaths', 'Scarface', 'Collateral', 'Sin City', "That's Life", 'El Mariachi', 'John Wick']
#
# === Topic 136: dragon, wizard, kingdom, viking, sword ===
# ['Aquaman', 'Harry Potter and the Goblet of Fire', 'Harry Potter and the Half-Blood Prince', 'Eragon', 'Kingsman: The Golden Circle', 'The Hobbit: The Battle of the Five Armies', 'The Chronicles of Narnia: Prince Caspian', 'The Hobbit: An Unexpected Journey', 'The Lord of the Rings: The Fellowship of the Ring', 'The NeverEnding Story', 'How to Train Your Dragon', 'Percy Jackson: Sea of Monsters', 'Friday the 13th Part 2', 'The Lord of the Rings: The Two Towers', 'The Sword in the Stone', 'Thor: Ragnarok', 'The Lion King', 'The Lord of the Rings: The Return of the King', 'The Green Knight']
#
# === Topic 137: donkey, swamp, dragon, lord, netflix ===
# ['Shrek', 'Shrek Forever After', 'Shrek the Third', 'Shrek 2']
#
# === Topic 138: war, soldiers, battle, allied, ii ===
# ['1917', 'Star Wars: The Force Awakens', '300', '300: Rise of an Empire']
#
# === Topic 139: film, wars, movie, documentary, films ===
# ["Jodorowsky's Dune", 'Harry Potter 20th Anniversary: Return to Hogwarts']
#
# === Topic 141: resistance, war, nazi, occupied, german ===
# ['Inglourious Basterds']
#
# === Topic 142: secret, secrets, family, buried, dark ===
# ['Compulsion', 'The Ghost Writer', 'Security']
#
# === Topic 143: school, high, student, tokyo, japan ===
# ['Ju-on: The Final Curse', 'Departures', 'Sadako vs. Kayako', 'Drive My Car', 'Challengers']
#
# === Topic 144: new, girl, life, girls, woman ===
# ['Sweetie', 'La La Land', 'The Neon Demon', 'The Outside', 'The Adventures of Priscilla, Queen of the Desert', 'Funeral Parade of Roses', 'Focus']
#
# === Topic 146: robot, cyborg, robots, machine, future ===
# ['Transformers: Age of Extinction', 'Terminator Salvation', 'Rise of the Planet of the Apes', 'Terminator: Dark Fate', 'The Matrix Reloaded', 'Pacific Rim', 'Transformers', 'Terminator Genisys', 'I Can Quit Whenever I Want 2: Masterclass', 'The Matrix Revolutions', 'Terminator 3: Rise of the Machines', 'X-Men: The Last Stand', 'Transformers: Dark of the Moon']
#
# === Topic 147: football, coach, team, players, basketball ===
# ['High School Musical 2']
#
# === Topic 148: china, chinese, hong, kong, li ===
# ['The Mummy: Tomb of the Dragon Emperor', 'Queer', 'Everything Everywhere All at Once', 'Days of Being Wild', 'Shang-Chi and the Legend of the Ten Rings']
#
# === Topic 149: princess, fairy, mermaid, godmother, kingdom ===
# ['The Magic Flute', 'Frozen', 'Sleeping Beauty', 'Snow White and the Seven Dwarfs', 'Beauty and the Beast', 'Aladdin', 'The Little Mermaid', 'Anora', 'Beauty and the Beast', 'Encanto', 'Maleficent', 'Wicked', 'Son of the White Mare', 'The Wizard of Oz', 'Wonder Woman']
#
# === Topic 150: dinosaurs, dinosaur, prehistoric, extinction, earth ===
# ['Jurassic Park', 'The Vanishing', 'The Lost World: Jurassic Park', 'Night at the Museum', 'Dinosaur', 'How to Train Your Dragon 2', 'Jurassic World', 'Jurassic World: Fallen Kingdom', 'Jurassic World Dominion']
#
# === Topic 154: film, death, video, camera, tape ===
# ['Ring', 'Ju-On: White Ghost']
#
# === Topic 155: mother, daughter, mom, single, father ===
# ["Pan's Labyrinth", 'The Gift', 'The Boy', 'Mamma Mia!', 'Roma', 'Ghostland', 'Mama']
#
# === Topic 156: terror, monster, frankenstein, creature, brain ===
# ['Saw 3D', 'Texas Chainsaw Massacre']
#
# === Topic 159: husband, wife, man, woman, married ===
# ['Bridget Jones: The Edge of Reason', 'Extremely Wicked, Shockingly Evil and Vile', 'A Couch in New York', 'Three Colours: Red', 'A Million Ways to Die in the West', 'Eyes Wide Shut', 'Black Bag', 'Nocturnal Animals', 'Marnie', 'Dial M for Murder']
#
# === Topic 160: murder, death, killer, dead, murdered ===
# ['I Still Know What You Did Last Summer', 'The Ward', 'Perfect Blue', 'Twin Peaks: Fire Walk with Me', 'Ju-On: Black Ghost', 'Scream 4', 'The Ring', 'MaXXXine', 'The Exorcism of Emily Rose', 'Kill Bill: Vol. 2', 'Drag Me to Hell']
#
# === Topic 161: ukrainian, wife, russian, moscow, young ===
# ['Come and See', 'The Girl with the Dragon Tattoo', 'The Girl Who Played with Fire', 'Three Colours: White']
#
# === Topic 164: documentary, series, interviews, fans, television ===
# ['Money Shot: The Pornhub Story']
#
# === Topic 165: concert, album, performance, tour, performances ===
# ['Trap']
#
# === Topic 169: trial, lawyer, attorney, accused, justice ===
# ["The Girl Who Kicked the Hornet's Nest", 'Primal Fear', 'Anatomy of a Murder', 'The Lincoln Lawyer', '12 Angry Men', 'The Verdict']
#
# === Topic 171: ship, sea, island, cruise, ocean ===
# ['The Lighthouse', 'Alien: Covenant', 'Adrift', 'The Legend of 1900', 'Triangle of Sadness']
#
# === Topic 175: snow, ski, summit, mountain, climb ===
# ['Everest', 'Frozen', 'Crawl', 'The Hunger Games: Mockingjay – Part 2']
#
# === Topic 179: wife, stubborn, council, life, caste ===
# ['The Shrouds', 'Disturbia']
#
# === Topic 180: music, album, documentary, punk, metal ===
# ['Crimes of the Future']
#
# === Topic 182: director, film, scenes, cast, actor ===
# ['Mank']
#
# === Topic 190: million, money, lottery, 000, gambling ===
# ['Run Lola Run', 'The Laundromat', 'Into the Wild', "Ocean's Eleven", "Ocean's Thirteen", 'The Wolf of Wall Street', 'Trading Places']
#
# === Topic 191: concert, beatles, album, tour, concerts ===
# ['Let It Be']
#
# === Topic 192: berlin, germany, german, young, family ===
# ['The Girl with the Dragon Tattoo', 'The Monitor', 'The Zone of Interest']
#
# === Topic 193: missing, girl, disappearance, daughter, vanished ===
# ['The Grudge 2', 'Under the Silver Lake', 'The Wicker Man', 'Dreams in the Witch House', 'You Were Never Really Here', 'Family Plot', 'Searching', 'The Girl in the Fog', 'Spinning Man', 'Missing']
#
# === Topic 194: drug, marijuana, drugs, heroin, cocaine ===
# ['The Gentlemen', 'The Substance', 'Requiem for a Dream', 'I Can Quit Whenever I Want', 'Trainspotting', 'Dazed and Confused', "We're the Millers", 'The Counselor']
#
# === Topic 195: miners, nuclear, coal, explosion, energy ===
# ['Killers of the Flower Moon', 'The Simpsons Movie']
#
# === Topic 196: dog, dogs, canine, puppy, stray ===
# ['Amores Perros', 'The King of Comedy', 'Dogman', 'Sausage Party', 'Dogman', 'Isle of Dogs']
#
# === Topic 198: presidential, president, election, trump, campaign ===
# ['The Big Short', 'Jackie', 'Vice', 'Sense8: Happy F*cking New Year', "All the President's Men", 'Election', 'The Post', 'The Hunger Games: The Ballad of Songbirds & Snakes']
#
# === Topic 202: marvel, spider, superhero, avengers, superheroes ===
# ['Spider-Man', 'X2', 'Deadpool 2', 'Star Wars', 'Ant-Man', 'Avengers: Infinity War', 'X-Men: First Class', 'The New Mutants', 'Captain Marvel', 'Iron Man', 'Thor', 'Spider-Man: Across the Spider-Verse', 'Captain America: The Winter Soldier', 'X-Men', 'Fantastic Four: Rise of the Silver Surfer', 'Iron Man 2', 'The Suicide Squad', 'Captain America: Civil War', 'Kick-Ass', 'Ant-Man and the Wasp: Quantumania', 'Iron Man 3', 'Deadpool', 'Spider-Man: Into the Spider-Verse', 'X-Men: Days of Future Past', 'X-Men: Apocalypse', 'The Incredible Hulk', 'Captain America: The First Avenger', 'The Marvels', 'Thor: Love and Thunder', 'Deadpool & Wolverine', 'Dark Phoenix', 'Avengers: Age of Ultron', 'Justice League', 'X-Men Origins: Wolverine', 'Spider-Man: No Way Home']
#
# === Topic 203: documentary, film, footage, films, filmed ===
# ['The Blair Witch Project']
#
# === Topic 206: actress, life, woman, career, fame ===
# ['Black Mirror: Fifteen Million Merits', 'Persona', 'Last Night in Soho', 'Florence Foster Jenkins']
#
# === Topic 208: world, rain, sun, end, tower ===
# ['City of Ember', 'The Order of Time']
#
# === Topic 209: lupin, statue, thief, stolen, gold ===
# ['The Pink Panther 2', 'A Fish Called Wanda', 'Indiana Jones and the Kingdom of the Crystal Skull', 'National Treasure', 'The Monuments Men']
#
# === Topic 211: experiment, scientific, scientists, experiments, scientist ===
# ['Solaris', 'Annihilation', 'Stereo (Tile 3B of a CAEE Educational Mosaic)', "Fermat's Room"]
#
# === Topic 213: robot, robots, robotic, programmed, humans ===
# ['RoboCop', 'Ex Machina', 'The Wild Robot', 'WALL·E', 'I, Robot']
#
# === Topic 214: covid, pandemic, 19, crocodile, wily ===
# ['Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan']
#
# === Topic 215: computer, hacker, computers, digital, technology ===
# ['Live Free or Die Hard', 'The Social Network', 'Inception', 'THX 1138', 'The Matrix', 'Alphaville', 'Primer', 'The Circle', 'The Imitation Game', 'Transcendence']
#
# === Topic 217: witch, witches, devil, witchcraft, possessed ===
# ['Fear Street: 1666', 'Hansel & Gretel: Witch Hunters', 'Viy', 'Annabelle: Creation', "Howl's Moving Castle", 'The Exorcist']
#
# === Topic 218: death, dead, die, life, man ===
# ['Enter the Void', 'Mickey 17', 'Biutiful', 'Network', 'Puss in Boots: The Last Wish', 'Misery', 'The Martian', 'I Am Legend', 'The Dead Zone', 'What Dreams May Come']
#
# === Topic 219: cop, police, cops, officer, officers ===
# ['Pineapple Express', 'Mad Max', 'Carry-On', 'Chungking Express', 'Assault on Precinct 13', 'ACAB : All Cops Are Bastards', 'Three Billboards Outside Ebbing, Missouri']
#
# === Topic 222: hide, secrets, secret, lock, hidden ===
# ['Next Door', 'Glorious']
#
# === Topic 223: old, family, father, parents, year ===
# ['Joyland', 'Manchester by the Sea', 'Cheaper by the Dozen', 'Where Am I Going?', "Harry Potter and the Philosopher's Stone", 'American Beauty']
#
# === Topic 230: year, old, mother, father, lennon ===
# ['The Idea of You']
#
# === Topic 233: paris, françois, revolution, life, parisian ===
# ['The French Dispatch', 'Pierrot le Fou', 'Hugo', 'The Dreamer', 'The Hunchback of Notre Dame']
#
# === Topic 237: baseball, league, team, game, sports ===
# ['Moneyball']
#
# === Topic 239: world, life, story, people, documentary ===
# ['Mad Max: Fury Road', 'Cloud Atlas', 'The Brutalist', 'Here', 'Mortal Engines', 'Koyaanisqatsi', 'Metropolis']
#
# === Topic 240: metro, villain, brain, gadgets, teammates ===
# ['Megamind']
#
# === Topic 241: killer, murder, serial, kill, killers ===
# ['The House That Jack Built', 'Thanksgiving', 'Four Flies on Grey Velvet', 'M', 'Taste of Cherry', 'Deathtrap', "Omicidio all'italiana", 'No Country for Old Men', 'Machete', 'The Grudge 3', 'The Crow', 'Saw X', 'Saw V', 'The Last Prosecco']
#
# === Topic 244: mouse, rats, rat, mice, cheese ===
# ['Flushed Away', 'Ratatouille']
#
# === Topic 247: man, life, young, world, shaman ===
# ['Spider', 'The Village', 'Italiano medio', 'Bruce Almighty', 'Falling Down', 'Naked', 'Limitless', 'Daredevil', 'The Father', 'Nightmare Alley', 'Ace in the Hole']
#
# === Topic 248: life, new, young, woman, mother ===
# ['After We Fell', 'After We Collided', 'After Ever Happy', 'After Everything', 'The Fault in Our Stars', 'Crimson Peak', 'Fifty Shades of Grey', "Bridget Jones's Diary", 'TÁR', 'Vortex']
#
# === Topic 249: company, store, employees, customers, workers ===
# ['The Devil Wears Prada', 'Baby Driver', 'Horrible Bosses', 'Cosmopolis', 'Exam', 'The Full Monty', 'A Cure for Wellness', 'Super Size Me 2: Holy Chicken!', 'Five Easy Pieces', 'Zoolander 2', 'The Internship']
#
# === Topic 250: tardis, doctor, planet, spaceship, companions ===
# ['Doctor Strange in the Multiverse of Madness']
#
# === Topic 252: painter, portrait, painting, artist, paintings ===
# ['Loving Vincent', 'The Great Beauty', 'Portrait of a Lady on Fire', 'Tear Along the Dotted Line', 'Phantom Thread']
#
# === Topic 254: terrorists, terrorist, muslim, afghanistan, war ===
# ['Akira']
#
# === Topic 258: sex, porn, sexual, erotic, sexuality ===
# ['Crash', 'Road Trip', 'Boogie Nights']
#
# === Topic 259: comedy, circus, man, life, amusement ===
# ['Death Sentence', 'Super Size Me', 'Zoolander', 'Bedtime Stories', 'Night at the Museum: Battle of the Smithsonian', 'The Incredibles', 'Groundhog Day']
#
# === Topic 261: alien, aliens, earth, space, planet ===
# ['Alien³', 'They Live', 'District 9', 'Alien Resurrection', 'The Fly', 'Fantastic Four', 'Planet of the Apes', 'Arrival', 'Killer Klowns from Outer Space', 'AVP: Alien vs. Predator', 'E.T. the Extra-Terrestrial', 'Aliens', 'Alien', 'Alien: Romulus']
#
# === Topic 262: city, new, york, life, journey ===
# ['BARDO, False Chronicle of a Handful of Truths', 'Midsommar', 'The Imaginarium of Doctor Parnassus', 'Brooklyn', 'Io Capitano']
#
# === Topic 264: school, high, college, education, students ===
# ['School of Rock', 'Klaus', 'The Perks of Being a Wallflower', '21']
#
# === Topic 265: woman, young, erotic, girl, dance ===
# ['Valerie and Her Week of Wonders', 'Lola', 'Kinds of Kindness']
#
# === Topic 268: mermaid, princess, fairies, babysitting, sisters ===
# ['Barbie']
#
# === Topic 269: girl, girls, young, wonderland, magical ===
# ['The Host']
#
# === Topic 270: zombie, zombies, undead, virus, dead ===
# ['Super 8', 'Dawn of the Dead', 'Resident Evil: Apocalypse', 'One Cut of the Dead', 'Train to Busan']
#
# === Topic 271: husband, housewife, family, life, home ===
# ['Gone with the Wind', 'The Help']
#
# === Topic 272: anthology, tales, horror, stories, directors ===
# ['Black Mirror: White Christmas']
#
# === Topic 276: bond, agent, bonds, spy, organization ===
# ['Die Another Day', 'Moonraker', 'Spectre', 'No Time to Die', 'Tomorrow Never Dies', 'Licence to Kill', 'Dr. No', 'Live and Let Die', 'A View to a Kill', 'From Russia with Love', 'Thunderball', 'Becoming Bond', 'Skyfall', 'The World Is Not Enough', 'Quantum of Solace', 'Casino Royale', 'For Your Eyes Only', 'The Living Daylights']
#
# === Topic 277: platoon, army, soldiers, soldier, patrol ===
# ['The Men Who Stare at Goats', 'Source Code', 'American Sniper', 'First Blood', 'Golden Men', 'Mine', 'Beau Travail', 'Blood Diamond']
#
# === Topic 278: house, safe, apartment, building, terrorized ===
# ['Leave the World Behind', 'The Raid', 'Better Watch Out', 'Panic Room', 'Harry Potter and the Chamber of Secrets']
#
# === Topic 281: hospital, memorial, admitted, serial, stubborn ===
# ['Halloween']
#
# === Topic 282: fear, afraid, fears, new, paranoia ===
# ['Zombieland', 'Repulsion', 'Inside Out 2']
#
# === Topic 283: feline, cats, sits, zoo, black ===
# ['Flow']
#
# === Topic 289: halloween, horror, nightmare, evil, ghost ===
# ['The Black Phone', 'Doctor Sleep', 'Scream 2', 'Scrooged', 'A Nightmare on Elm Street', 'Halloween', 'Terrifier 2', "A Nightmare on Elm Street Part 2: Freddy's Revenge", 'Halloween', 'Halloween Ends']
#
# === Topic 292: pokémon, basketball, sunset, twilight, match ===
# ['Pokémon the Movie: I Choose You!']
#
# === Topic 296: man, woman, life, young, lover ===
# ['Baby Reindeer', 'Hard Eight', 'Punch-Drunk Love', 'Me Before You', 'Tetsuo: The Iron Man', 'City Lights', 'Sympathy for Mr. Vengeance']
#
# === Topic 297: prison, inmates, convicts, justice, crime ===
# ['Sleepers', 'Irreversible', 'The Purge']
#
# === Topic 299: chicken, birds, eggs, egg, crow ===
# ['The Birds', 'Chicken Little', 'Lucky and Zorba']
#
# === Topic 301: party, guests, dinner, wedding, hotel ===
# ['The Menu', 'Perfect Strangers', 'Coherence', 'Superbad', 'Clue', 'Four Rooms', 'The Hangover Part II', 'Gli ospiti']
#
# === Topic 306: toy, toys, boy, children, child ===
# ['Charlie and the Chocolate Factory', 'Toy Story 4', 'Mary Poppins', 'Jumanji', 'Toy Story 3', 'Toy Story', 'The Iron Giant', 'Incredibles 2', 'Labyrinth', 'Tangled']
#
# === Topic 309: brazilian, brazil, são, film, joão ===
# ['Baggio: The Divine Ponytail']
#
# === Topic 312: emperor, rome, potion, empire, slave ===
# ['Freaks Out', 'The First King', 'Gladiator', 'War for the Planet of the Apes', 'Troy']
#
# === Topic 313: truth, journalist, journalists, news, story ===
# ['Bombshell', 'Civil War']
#
# === Topic 315: monster, monsters, frankenstein, ghouls, dracula ===
# ['Pokémon Detective Pikachu', 'Candyman', 'Monsters, Inc.']
#
# === Topic 317: group, strangers, residents, friends, small ===
# ['Hostel', 'And Then There Were None', 'The Texas Chain Saw Massacre', 'Night of the Living Dead', 'Bad Times at the El Royale', 'Sin City: A Dame to Kill For', 'Funny Games', 'They Cloned Tyrone', 'Cube']
#
# === Topic 323: pig, farmer, sheep, horse, pigs ===
# ['The Black Cauldron', 'Home on the Range']
#
# === Topic 324: man, mysterious, psychic, mind, insane ===
# ['Unknown', 'Scanners', 'Strangers on a Train', 'Circle', 'The Tenant', 'The Place', 'The Fog', 'The Conjuring: The Devil Made Me Do It', 'Shutter Island', '1408', 'Unbreakable', 'Oldboy', 'Poltergeist', 'The Brood', "The Cat o' Nine Tails", 'Deep Red', 'Glass', 'Ghost Stories']
#
# === Topic 326: woman, raped, girl, young, story ===
# ['Thesis', 'Ju-on: The Grudge', 'Martyrs']
#
# === Topic 329: nun, convent, nuns, church, religious ===
# ['The First Omen', 'Sister Act', 'Silence', 'The Others']
#
# === Topic 330: animated, animation, disney, film, short ===
# ['Dragon Ball DAIMA']
#
# === Topic 334: father, home, missing, man, family ===
# ['Skinamarink', 'The Judge', 'Indiana Jones and the Last Crusade', 'Paris, Texas', 'Lion', 'Inkheart', 'This Must Be the Place', 'The Sacrament', 'Swiss Army Man', 'The American Backyard']
#
# === Topic 338: band, album, punk, concert, music ===
# ['Fear Street: 1978', 'Hop', 'Bohemian Rhapsody', 'Alvin and the Chipmunks', "Ocean's Twelve"]
#
# === Topic 339: old, year, school, girl, best ===
# ['It Follows', 'A Walk to Remember', 'Mean Girls', 'Prisoners', 'Forever-Forever', 'After']
#
# === Topic 340: dictatorship, spanish, brazil, chile, argentina ===
# ["The Devil's Backbone", 'Bananas', 'City of God', 'Fascists on Mars']
#
# === Topic 341: cia, soviet, agent, nuclear, spy ===
# ['The Interview', 'Argo', 'Olympus Has Fallen', 'Mission: Impossible – Ghost Protocol', 'Bridge of Spies', 'Topaz', 'Angels & Demons', 'Captain America: Brave New World', 'November', 'The Spy Who Loved Me', 'National Treasure: Book of Secrets', 'Vantage Point']
#
# === Topic 344: terror, begins, new, nightmare, house ===
# ['Insidious: Chapter 3']
#
# === Topic 345: jungle, elephant, cub, desert, animals ===
# ['The Wild', 'Ice Age', 'Tarzan', 'Bambi', 'Snow Leopard', 'The Jungle Book']
#
# === Topic 346: father, mother, story, family, life ===
# ['Incendies', 'Boyhood', 'Captain Fantastic', 'Eraserhead', 'Monolith']
#
# === Topic 350: woman, man, young, life, falls ===
# ['Forrest Gump']
#
# === Topic 353: friends, friendship, best, friend, life ===
# ['La Haine', 'Nothing Left to Do But Cry', 'Monsters University', 'Past Lives', 'West Side Story', 'The Big Chill', 'The Descent', 'Friends: The Reunion', 'Last Vegas', 'The Florida Project', 'Brain Drain', 'Belfast', "The World's End", 'My Friends', 'The Hangover']
#
# === Topic 354: time, future, past, machine, travel ===
# ['Meet the Robinsons', 'Looper', 'Knowing', 'In Time', 'Inferno']
#
# === Topic 356: father, family, life, man, young ===
# ['War of the Worlds', 'Nebraska', 'The Celebration', 'The Rich, the Pauper and the Butler', 'The Great Gatsby', 'Bean', 'The Apprentice', 'The Pursuit of Happyness', 'All the Money in the World', 'Close Enemies']
#
# === Topic 359: italy, italian, rome, naples, sicily ===
# ['Last Night of Amore', 'Fantozzi: White Collar Blues', 'The Traitor', 'Welcome Mr. President!', 'Loro 2', 'Rose Island', 'Women Vs Men', '8½', 'Hannibal', "Don't Be Bad", 'The Night Before the Exams Today', 'Life Is Beautiful', 'Loro 1', 'Welcome to the South', 'The Decameron', 'Inferno', 'The Godfather Part II', 'Three Men and a Leg', 'Megalopolis', 'The Night Before the Exams', 'The Hand of God']
#
# === Topic 360: husband, wife, woman, married, affair ===
# ['Chloe', 'Three Colours: Blue', 'Sleuth', 'sex, lies, and videotape', 'Possession', 'Ready or Not']
#
# === Topic 361: rabbit, bugs, wonderland, bull, owl ===
# ['Donnie Darko']
#
# === Topic 362: spain, argentina, madrid, military, cases ===
# ['Polytechnique']
#
# === Topic 363: pluto, goofy, mouse, disney, christmas ===
# ['Mickey, Donald, Goofy: The Three Musketeers', 'Fun and Fancy Free', "Mickey's Twice Upon a Christmas"]
#
# === Topic 366: wife, married, vegas, family, house ===
# ['Horrible Bosses 2', 'Psycho', 'Meet the Fockers', 'Meet the Parents', 'The Rocky Horror Picture Show', 'Naked', 'Love', 'The Irishman']
#
# === Topic 370: queen, throne, princess, england, kingdom ===
# ["A Knight's Tale"]
#
# === Topic 371: yakuza, tokyo, ninja, japan, boss ===
# ['Gran Torino']
#
# === Topic 373: train, passengers, station, railway, subway ===
# ['Black Mirror: Smithereens', 'Blind Chance', 'Stagecoach']
#
# === Topic 375: nazi, hitler, german, war, ii ===
# ['Oppenheimer', "Schindler's List", 'Dunkirk', 'All Quiet on the Western Front', 'Downfall', 'Jojo Rabbit']
#
# === Topic 376: mission, mercenaries, assassin, team, mercenary ===
# ['Now You See Me 2', 'Thunderbolts*', 'Project Power', 'Watchmen', 'Mission: Impossible – Rogue Nation', 'Rogue One: A Star Wars Story', 'Tenet', 'Bullet Train', 'Mission: Impossible – Fallout', 'Black Mirror: Beyond the Sea', 'Fast & Furious 6', 'Mission: Impossible – Dead Reckoning', 'Sense8: Amor Vincit Omnia', 'Mission: Impossible III', 'John Wick: Chapter 2', 'Predator', 'Suicide Squad']
#
# === Topic 377: frankenstein, scientist, monster, dr, mad ===
# ['Young Frankenstein', 'Frankenstein', 'Victor Frankenstein', "Mary Shelley's Frankenstein", 'The Elephant Man', 'Hulk', 'A Dangerous Method']
#
# === Topic 378: outlaw, ranch, cattle, sheriff, cowboy ===
# ['The Good, the Bad and the Ugly', 'A Fistful of Dollars', 'The Revenant', 'The Ballad of Buster Scruggs', 'For a Few Dollars More', 'The Devil All the Time', 'True Grit', 'They Call Me Trinity']
#
# === Topic 379: evil, new, demonic, young, puppet ===
# ['Late Night with the Devil']
#
# === Topic 385: new, life, mother, family, father ===
# ['Pet Sematary', 'Evil Dead', 'The Invisible Witness', 'Scary Movie 4', 'The Secret of Moonacre', 'Red Riding Hood']
#
# === Topic 390: woman, life, young, old, past ===
# ['Coraline', 'Anomalisa', 'The Beyond', 'Poor Things', 'Nomadland', 'Titane', "There's Still Tomorrow"]
#
# === Topic 391: falls, japanese, immigrant, american, woman ===
# ['Casablanca']
#
# === Topic 393: music, singer, musician, pianist, songs ===
# ["Jacob's Ladder", 'A Clockwork Orange', 'CODA', 'Lost Highway', 'Sound of Metal']
#
# === Topic 394: bank, robbery, heist, robbers, thieves ===
# ['Reservoir Dogs', 'Inside Man', 'High and Low', 'Fargo', 'Point Break']
#
# === Topic 395: boxing, boxer, champion, champ, wrestling ===
# ['Rocky V', 'Pulp Fiction', 'Rocky', 'Brawl in Cell Block 99', 'Rocky III', 'Indiana Jones and the Dial of Destiny', 'Creed', 'Creed III', 'Rocky IV', 'Snatch', 'Rocky II', 'DodgeBall: A True Underdog Story', 'Rocky Balboa', 'Raging Bull', 'Real Steel']
#
# === Topic 397: life, new, girlfriend, young, old ===
# ['The Intern', 'The Fast and the Furious: Tokyo Drift', 'Birdman or (The Unexpected Virtue of Ignorance)', 'The Big Lebowski', 'Youth', 'Ghost Rider', 'Toy Story 2', 'Death Proof', 'Click']
#
# === Topic 399: comedian, comedy, comedians, stand, special ===
# ['The Cosmos on the Commode', 'Joker', 'Between Two Ferns: The Movie', 'Ricky Gervais: Humanity', 'Bo Burnham: Inside', 'Videodrome', 'Death to 2021']
#
# === Topic 402: film, movie, man, comedy, life ===
# ['Point Break', 'Close-Up', 'Creep', 'X', 'Super Fantozzi']
#
# === Topic 404: food, farming, farmers, farmer, chef ===
# ['Just Believe', 'Parasite']
#
# === Topic 405: hunters, hunted, hunting, wildlife, woods ===
# ['The Hateful Eight', 'Wrong Turn', 'Bone Tomahawk', 'Predators']
#
# === Topic 412: dog, zoo, animals, cub, puppy ===
# ["Madagascar 3: Europe's Most Wanted", 'Life of Pi', 'Madagascar', 'Beverly Hills Chihuahua', 'The Fox and the Hound', 'Marley & Me']
#
# === Topic 413: pan, hook, darling, grandpa, captain ===
# ['Peter Pan', 'Spider-Man: Far From Home', 'Spider-Man 2', 'Hook', 'Due Date', 'The Amazing Spider-Man', 'Guardians of the Galaxy Vol. 2', 'The Amazing Spider-Man 2']
#
# === Topic 416: batman, gotham, league, joker, superman ===
# ['The Dark Knight Rises', 'Batman', 'The Batman', 'Batman Begins', 'The Dark Knight']
#
# === Topic 418: ocean, submarine, water, sea, underwater ===
# ['Deliverance', 'The Commander', 'Atlantis: The Lost Empire']
#
# === Topic 420: nba, basketball, olympic, sports, olympics ===
# ['Air']
#
# === Topic 424: holmes, crime, criminal, jewels, reigns ===
# ['Sherlock Holmes: A Game of Shadows']
#
# === Topic 428: angels, wings, heaven, afterlife, god ===
# ['Hot Fuzz']
#
# === Topic 429: india, mumbai, cricket, indian, kerala ===
# ['Stolen']
#
# === Topic 431: boy, young, boys, old, story ===
# ['The Sixth Sense', 'Sky High', 'Man of Steel', 'Shazam!', "Guillermo del Toro's Pinocchio", 'Room']
#
# === Topic 435: game, games, play, video, contestants ===
# ['eXistenZ', 'Pixels', 'Jumanji: Welcome to the Jungle', 'The Hunger Games', 'Saw IV', 'The Hunger Games: Catching Fire', 'Choose or Die', 'Black Mirror: Bandersnatch', 'The Last of Sheila', 'Ready Player One']
#
# === Topic 436: horse, bus, passengers, speed, frantically ===
# ['The Similars']
#
# === Topic 438: boyfriend, girl, night, woman, new ===
# ['Scott Pilgrim Takes Off', 'Dead Silence', 'Dead Ringers', 'Game Night', "Gerald's Game", 'The Guest Room', 'Ghosts of Girlfriends Past', 'Body Double']
#
# === Topic 439: school, student, girl, high, crush ===
# ['The Graduate', 'High School Musical']
#
# === Topic 444: paris, françois, life, young, year ===
# ['Roman Holiday', 'A Christmas Tale', 'Out of Season', 'Forever Young']
#
# === Topic 446: scooby, doo, shaggy, gang, mystery ===
# ['Scooby-Doo']
#
# === Topic 450: iran, istanbul, father, tehran, family ===
# ['Ali G Indahouse']
#
# === Topic 451: goku, dragon, warriors, dragons, warrior ===
# ['Furiosa: A Mad Max Saga', 'Dragon Ball Super: Broly', 'Black Panther: Wakanda Forever', 'How to Train Your Dragon: The Hidden World', 'Dragon Ball Z: Battle of Gods', 'Jumanji: The Next Level', 'The Lion King', "Dragon Ball Z: Resurrection 'F'", 'The Last Airbender']
#
# === Topic 455: tokyo, japan, family, mother, old ===
# ['The Boy and the Heron', 'Tokyo Story', 'Love Life']
#
# === Topic 457: strangers, couple, meet, lives, young ===
# ['Carnage', 'The Fisher King', 'House of 1000 Corpses', 'Y Tu Mamá También', 'The Intouchables', 'Human Capital', 'A Rainy Day in New York']
#
# === Topic 462: soo, jin, ji, hyun, tae ===
# ['The Handmaiden']
#
# === Topic 480: dance, ballet, dancers, dancer, dancing ===
# ['Black Swan', 'Suspiria', 'Climax']
#
# === Topic 481: village, warrior, goddess, tribe, life ===
# ['Bāhubali: The Beginning', 'Prey', 'Black Panther']
#
# === Topic 482: school, friends, crush, friend, cheerleader ===
# ['Match Point', 'Ted', 'The 40 Year Old Virgin', 'Shame', 'Get Out', 'Scott Pilgrim vs. the World']
#
# === Topic 483: adventure, expedition, explorers, adventurers, world ===
# ['Interstellar', 'The Chronicles of Narnia: The Voyage of the Dawn Treader', 'The Lost City of Z', 'Kong: Skull Island', 'Death on the Nile', 'Raiders of the Lost Ark', 'Journey to the Center of the Earth', 'King Kong', 'Planet of the Apes']
#
# === Topic 485: lover, triangle, young, falls, woman ===
# ['Shakespeare in Love', 'Maestro', 'Joker: Folie à Deux']
#
# === Topic 486: relationship, romance, couple, romantic, lovers ===
# ['Vicky Cristina Barcelona', 'Before Midnight', 'Men Vs Women', 'Wild at Heart', 'Before Sunset']
#
# === Topic 488: brothers, sisters, siblings, twins, brother ===
# ['Breaking Surface', 'Three Identical Strangers', 'The Prince of Egypt', 'The Visit', 'The Last Mimzy', 'Onward', 'Sinners', "Don't Look Now", 'From Dusk Till Dawn', "Before the Devil Knows You're Dead"]
#
# === Topic 489: cop, detective, police, fbi, killer ===
# ['Twelve Monkeys', 'Blade Runner 2049', 'Die Hard With a Vengeance', 'Longlegs', 'American History X', 'Spiral: From the Book of Saw', 'The Purge: Election Year', 'Fast Five', 'The Killer', 'Presumed Innocent', 'Lethal Weapon', 'Speed', 'Miami Vice', 'Fast & Furious', 'The Equalizer', 'Killing Them Softly', 'Snake Eyes', 'Saw VI', 'The Usual Suspects', 'No Way Out']
#
# === Topic 491: magic, magician, magical, sorcerer, wizard ===
# ["The Sorcerer's Apprentice", 'Fantastic Beasts: The Secrets of Dumbledore', 'Night at the Museum: Secret of the Tomb', "Mr. Magorium's Wonder Emporium", 'Harry Potter and the Deathly Hallows: Part 2', 'Oz the Great and Powerful', 'Doctor Strange']
#
# === Topic 494: hollywood, actor, stars, movie, stardom ===
# ['Maps to the Stars', 'Hail, Caesar!', 'The Disaster Artist']
#
# === Topic 496: hostage, escape, kidnapped, prisoner, border ===
# ['The Man Who Knew Too Much', 'No Escape', 'Knock at the Cabin', 'Identity', 'Taken 2', 'Green Border', 'Django Unchained']

# %%
df_test.Topic.nunique()
# Out:
# 127

# %% [markdown]
# ### Inference

# %%
import joblib
from sentence_transformers import SentenceTransformer
import pandas as pd

joblib.dump(kmeans, "plottopic/kmeans_model.pkl")
joblib.dump(filtered_cluster_keywords, "plottopic/cluster_keywords.pkl")

# %%
sbert = SentenceTransformer("all-MiniLM-L6-v2", device="cpu")
kmeans = joblib.load("plottopic/kmeans_model.pkl")
keyword_map = joblib.load("plottopic/cluster_keywords.pkl")

def plottopic(text: str) -> str:
    emb = sbert.encode([text], show_progress_bar=False)
    label = kmeans.predict(emb)[0]
    return str(label) + "_" + "_".join(keyword_map[label])

# %%
test = pd.read_csv("ml_data/test.csv")

# %%
test['Topic'] = test.Plot.apply(plottopic)
for topic in sorted(test["Topic"].unique()):
    print(f"\n=== {topic.upper()} ===")
    print(test[test["Topic"] == topic]['Title'].to_list()[:20])
# Out:
# === 10_CREW_GAME_GANG_DETECTIVE_BROTHER ===
# ['Die Hard', '2 Fast 2 Furious', 'In Bruges']
#
# === 11_MURDER_REAL_FILM_CRIME_DAY ===
# ['The Secret Life of Walter Mitty', 'Knight of Cups', 'Boris: The Film']
#
# === 12_VILLAGE_POWERS_MOTHER_BOY_DAY ===
# ["The Emperor's New Groove", 'Ice Age: Dawn of the Dinosaurs', 'Princess Mononoke']
#
# === 13_MURDER_CRIME_DETECTIVE_KILLER_DEAD ===
# ["Ask Me If I'm Happy", 'El Conde', 'The Da Vinci Code', 'Nosferatu the Vampyre', 'Catch Me If You Can', 'GoodFellas']
#
# === 14_SISTER_TRUE_WOMAN_BEAUTIFUL_MOTHER ===
# ['Donkey Skin', 'Disenchanted', 'Cinderella', 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 'Aladdin', 'Saint Maud', 'Alice in Wonderland', 'Enchanted', 'Alice Through the Looking Glass', 'The Princess and the Frog']
#
# === 15_RELATIONSHIP_FRIENDS_COUPLE_END_YORK ===
# ['Revenge', 'Love Actually', 'Easy Rider', 'The Immature', 'The Banshees of Inisherin']
#
# === 17_MOTHER_YEAR_DAUGHTER_OLD_FATHER ===
# ['Pearl', 'Echo']
#
# === 18_FIGHT_LEFT_FACE_BATTLE_DRUG ===
# ['Creed II']
#
# === 19_BOND_SPACE_AGENT_SENT_GAME ===
# ["On Her Majesty's Secret Service", "Tom Clancy's Without Remorse", 'You Only Live Twice', 'GoldenEye']
#
# === 1_STORY_WAR_FILM_ARMY_LIVES ===
# ['Perfect Days', 'The Dictator', 'The Grand Budapest Hotel', 'Harakiri', 'Darkest Hour', 'A Man Escaped', 'Il Sorpasso']
#
# === 20_POWERS_SUPER_HIGH_SCHOOL_CITY ===
# ['Batman Returns', 'Spider-Man: Homecoming', 'Spider-Man 3']
#
# === 21_DEAD_GAME_DOCTOR_MAN_DETECTIVE ===
# ['Hannibal Rising', 'The Matrix Resurrections', '127 Hours', 'Guns Akimbo', 'National Theatre Live: Frankenstein', 'El Camino: A Breaking Bad Movie', 'Death Note', 'Sully']
#
# === 22_GANG_FUTURE_HEAD_RACE_CHILDREN ===
# ["It's a Wonderful Life", 'The Great Mouse Detective', 'Pinocchio', "Mickey's Once Upon a Christmas", 'Christmas Holidays']
#
# === 23_ISLAND_ESCAPE_CREW_TEAM_THINGS ===
# ['Jurassic Park III', 'Over the Hedge']
#
# === 24_GETS_POLICE_RUN_CRIME_PERSONAL ===
# ['Jackie Brown', 'Paycheck', 'The Second Tragic Fantozzi', 'The Game', 'Bee Movie', 'Logan Lucky', 'Take the Money and Run', 'Velvet Buzzsaw', 'Uncut Gems', 'American Psycho']
#
# === 25_DRUG_POLICE_GIRLFRIEND_WAR_AMERICAN ===
# ['All You Need is Crime', 'Sleep Tight', 'The Consequences of Love', 'Infernal Affairs', 'Seven Samurai', 'There Will Be Blood', 'Ghost Rider: Spirit of Vengeance', 'Suburra']
#
# === 26_EARTH_ALIEN_ENEMY_FORCE_FATE ===
# ['Guardians of the Galaxy Vol. 3', 'Fury']
#
# === 27_HOUSE_ROOM_WIFE_DAUGHTER_GAME ===
# ['It Chapter Two', 'Wings of Desire', 'Lake Mungo']
#
# === 28_WOMAN_ADVENTURE_LONDON_GREAT_FOREVER ===
# ['Alice in Wonderland', 'A Ghost Story']
#
# === 29_ADVENTURE_ROOM_GAME_THINGS_PARENTS ===
# ['Wonder Wheel', 'Space Jam']
#
# === 2_SPACE_PLANET_EARTH_ALIEN_CREW ===
# ['Dark Web: Descent Into Hell', 'Evan Almighty', 'Life', 'Asteroid City', 'Hellraiser', 'Lightyear']
#
# === 30_POWER_QUEST_ARMY_GREAT_NAMED ===
# ["The King's Speech"]
#
# === 31_CHANGE_PARENTS_MAKES_AWAY_QUEST ===
# ['Have You Met Claudia?']
#
# === 32_MURDER_KILLER_WANTS_DAUGHTER_BOY ===
# ['Zodiac', 'Totally Killer', 'Memento']
#
# === 33_FILM_RACE_CAR_CREW_LIKE ===
# ['Mixed by Erry', 'King Richard', 'The Truman Show', 'The Words', 'Black Mirror: Hotel Reverie', 'Ricky Gervais: SuperNature', 'The Other Side of the Wind', 'Milk', 'Borg vs McEnroe', 'The Chorus', 'Control']
#
# === 34_SAVE_BOY_EVIL_ANCIENT_FATHER ===
# ['Dragonball Evolution', 'Lady and the Tramp', 'Hercules', 'Exodus: Gods and Kings']
#
# === 35_WOMAN_DAUGHTER_NIGHT_SISTER_HUSBAND ===
# ['The Nun', 'America Latina']
#
# === 36_GIRL_WOMAN_MOTHER_KILLING_REVENGE ===
# ['Happy Death Day', "Child's Play", 'The Grudge', 'Eastern Promises', 'Dark Glasses', 'The Babadook', 'Carrie']
#
# === 37_BOND_AGENT_FACE_TRUTH_SPACE ===
# ['Manhunter', 'The Man with the Golden Gun']
#
# === 38_AGENT_MISSION_FUTURE_WAR_STOP ===
# ['A Good Day to Die Hard', 'Die Hard 2', 'American Hustle', 'Possessor', 'Taxi Driver', 'Good Will Hunting', 'Fast & Furious Presents: Hobbs & Shaw']
#
# === 39_EARTH_DESTROY_DARK_POWER_FATE ===
# ['The Hobbit: The Desolation of Smaug']
#
# === 3_RELATIONSHIP_SISTER_DAUGHTER_EX_WIFE ===
# ['Hitchcock', 'Silver Linings Playbook', 'The Babysitter', 'Malcolm & Marie', 'Once Upon a Time... in Hollywood', 'The Parent Trap']
#
# === 40_HOUSE_ROOM_SINISTER_STRANGE_DARK ===
# ["Pickman's Model", 'Talk to Me', 'House on Haunted Hill', 'Vampyr', 'A Quiet Place Part II', 'Zombeavers', 'What We Do in the Shadows']
#
# === 41_SCHOOL_STUDENT_PERSONAL_YEAR_MAKES ===
# ['Whiplash', 'An Officer and a Gentleman']
#
# === 42_LONDON_DEADLY_DETECTIVE_DESTROY_DESPERATE ===
# ['Fantastic Beasts: The Crimes of Grindelwald', 'My Bloody Valentine', 'Harry Potter and the Prisoner of Azkaban']
#
# === 44_RELATIONSHIP_BOY_WIFE_PARENTS_COUPLE ===
# ['7 and 8', 'Chappie', 'Call Me by Your Name', 'The Family Man']
#
# === 45_AGENT_TEAM_GANG_MISSION_GAME ===
# ['Snowden', 'Minority Report', 'Resident Evil']
#
# === 48_DETECTIVE_MURDER_KILLER_POLICE_CITY ===
# ['Blue Velvet', 'Heat', 'I Am the Abyss', 'The Naked Gun: From the Files of Police Squad!', 'The Woman in the Window']
#
# === 49_FAMILY_HOUSE_MOTHER_COUPLE_FATHER ===
# ['Over the Garden Wall', 'A Quiet Place', 'The Conjuring 2', 'Wrong Turn 6: Last Resort', 'Hereditary', 'Mystic River', 'The Orphanage', 'The Omen', 'Apostle']
#
# === 4_FUTURE_CITY_FOREVER_FATE_HUMANITY ===
# ['The Green Inferno', 'The Phantom Carriage', 'The Final Destination', 'Noah']
#
# === 5_POLICE_GANG_GOVERNMENT_SINISTER_KNOWN ===
# ['The First Purge', 'The Purge: Anarchy', 'The Warriors', 'BlacKkKlansman', 'Cloverfield', 'Kick-Ass 2', 'The Bling Ring', 'The Platform']
#
# === 6_SUPER_FORCES_POWERS_ALIEN_FACE ===
# ['Transformers: Revenge of the Fallen', 'The Wolverine', 'Star Wars: The Last Jedi', 'The Terminator', 'Terminator 2: Judgment Day', 'Batman v Superman: Dawn of Justice']
#
# === 7_RELATIONSHIP_SCHOOL_CHANGE_HIGH_STUDENT ===
# ['Touki Bouki', 'High School Musical 3: Senior Year']
#
# === 8_SPACE_TRAPPED_SUPER_GROUP_ENEMY ===
# ['Army of the Dead', 'Stalker', 'A Classic Horror Story', 'Scream VI', 'Eternals', 'Resident Evil: Extinction']
